# %% [markdown]
# # Assignment 10
# Find your favorite news source and grab the article text.
#
# 1. Show the most common words in the article.
# 2. Show the most common words under a part of speech. (i.e. NOUN: {'Bob':12, 'Alice':4,})
# 3. Find a subject/object relationship through the dependency parser in any sentence.
# 4. Show the most common Entities and their types.
# 5. Find Entites and their dependency (hint: entity.root.head)
# 6. Find the most similar words (noun chunks) in the article

# %%
import spacy
import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Washington Post Article:
# ### [Zuckerberg once wanted to sanction Trump. Then Facebook wrote rules that accommodated him.](https://www.washingtonpost.com/technology/2020/06/28/facebook-zuckerberg-trump-hate/)

# %%
text = """ Zuckerberg once wanted to sanction Trump. Then Facebook wrote rules that accommodated him.
Starting as early as 2015, Facebook executives started crafting exceptions for the then-candidate that transformed the world’s information battlefield for years to come.

Hours after President Trump’s incendiary post last month about sending the military to the Minnesota protests, Trump called Facebook chief executive Mark Zuckerberg.
The post put the company in a difficult position, Zuckerberg told Trump, according to people familiar with the discussions. The same message was hidden by Twitter, the strongest action ever taken against a presidential post.
To Facebook’s executives in Washington, the post didn’t appear to violate its policies, which allows leaders to post about government use of force if the message is intended to warn the public — but it came right up to the line. The deputies had already contacted the White House earlier in the day with an urgent plea to tweak the language of the post or simply delete it, the people said.
Eventually, Trump posted again, saying his comments were supposed to be a warning after all. Zuckerberg then went online to explain his rationale for keeping the post up, noting that Trump’s subsequent explanation helped him make his decision.
The frenzied push-pull was just the latest incident in a five-year struggle by Facebook to accommodate the boundary-busting ways of Trump. The president has not changed his rhetoric since he was a candidate, but the company has continually altered its policies and its products in ways certain to outlast his presidency.
Bowing to pressure, Facebook will start labeling violating posts from politicians. But critics say it’s not enough.
Facebook has constrained its efforts against false and misleading news, adopted a policy explicitly allowing politicians to lie, and even altered its news feed algorithm to neutralize claims that it was biased against conservative publishers, according to more than a dozen former and current employees and previously unreported documents obtained by The Washington Post. One of the documents shows it began as far back as 2015, when as a candidate Trump posted a video calling for a ban of Muslims entering the United States. Facebook’s executives declined to remove it, setting in motion an exception for political discourse.
The concessions to Trump have led to a transformation of the world’s information battlefield. They paved the way for a growing list of digitally savvy politicians to repeatedly push out misinformation and incendiary political language to billions of people. It has complicated the public understanding of major events such as the pandemic and the protest movement, as well as contributed to polarization.
And as Trump grew in power, the fear of his wrath pushed Facebook into more deferential behavior toward its growing number of right-leaning users, tilting the balance of news people see on the network, according to the current and former employees.
Facebook is now confronting a mounting advertiser boycott that has pushed down its stock price as companies demand stricter policies against hate speech. Starbucks became the latest on Sunday to say it would hit pause on social media advertising.
Facebook is also facing a slow-burning crisis of morale, with more than 5,000 employees denouncing the company’s decision to leave Trump’s post that said, “when the looting starts, the shooting starts,” up.

Bowing to those pressures on Friday, Zuckerberg announced a rash of new policies aimed at better policing content on the site. That includes affixing labels on posts that violate hate speech or other policies — even on those from political leaders.
But the company said the post wouldn’t have qualified.
As the United States heads into another presidential election while facing a pandemic and civil unrest, the latitude given to Trump may afford him a potential advantage. In recent months, he has used Facebook and other platforms to tout misleading information about coronavirus cures, election fraud and the motives of protesters, frequently targeting a left-wing movement as a cause of violence without citing evidence.
It also places Facebook in growing conflict with its counterparts in Silicon Valley. Twitter has labeled several presidential tweets as abusive and misleading, and social media platform Snapchat curtailed the reach of the president’s account.
“The value of being in favor with people in power outweighs almost every other concern for Facebook,” said David Thiel, a Facebook security engineer who resigned in March after his colleagues refused to remove a post he believed constituted “dehumanizing speech” by Brazil’s president.
Facebook contends the use of incendiary populist language predates social media. Nick Clegg, Facebook’s vice president for global affairs and communications, said in a statement that populism wasn’t invented in Silicon Valley, pointing to centuries of political history before social media companies’ existence.
Nick Clegg, Facebook's vice president of global affairs, said that populism wasn’t invented in Silicon Valley. (Kirsty Wigglesworth/AP)
“From the Arab Spring to local candidates challenging political incumbents, social media has also helped to open up politics, not favor one side over the other,” Clegg added. “Studies have shown the drivers of populism are complex and cannot be reduced to the use of social media, in fact political polarization has fallen in many countries with high internet use.”
Facebook declined to make Zuckerberg available for an interview, although it pointed out that Zuckerberg opposed Trump when his Muslim immigration ban went into effect. The White House declined to comment.
Zuckerberg talks frequently about making choices that stand the test of time, preserving the values of Facebook and subsidiaries WhatsApp and Instagram for all of its nearly 3 billion monthly users for many years into the future — even when those decisions are unpopular or controversial.
At one point, however, he wanted a different approach to Trump.
Setting the stage
Before the 2016 election, the company largely saw its role in politics as courting political leaders to buy ads and broadcast their views, according to people familiar with the company’s thinking.

But that started to change in 2015, as Trump’s candidacy picked up speed. In December of that year, he posted a video in which he said he wanted to ban all Muslims from entering the United States. The video went viral on Facebook and was an early indication of the tone of his candidacy.
Outrage over the video led to a companywide town hall, in which employees decried the video as hate speech, in violation of the company’s policies. And in meetings about the issue, senior leaders and policy experts overwhelmingly said they felt that the video was hate speech, according to three former employees, who spoke on the condition of anonymity for fear of retribution. Zuckerberg expressed in meetings that he was personally disgusted by it and wanted it removed, the people said. Some of these details were previously reported.
At one of the meetings, Monika Bickert, Facebook’s vice president for policy, drafted a document to address the video and shared it with leaders including Zuckerberg’s top deputy COO Sheryl Sandberg and Vice President of Global Policy Joel Kaplan, the company’s most prominent Republican.
The document, which is previously unreported and obtained by The Post, weighed four options. They included removing the post for hate speech violations, making a one-time exception for it, creating a broad exemption for political discourse and even weakening the company’s community guidelines for everyone, allowing comments such as “No blacks allowed” and “Get the gays out of San Francisco.”
Facebook spokesman Tucker Bounds said the latter option was never seriously considered.
The document also listed possible “PR Risks” for each. For example, lowering the standards overall would raise questions such as, “Would Facebook have provided a platform for Hitler?” Bickert wrote. A carveout for political speech across the board, on the other hand, risked opening the floodgates for even more hateful “copycat” comments.
Ultimately, Zuckerberg was talked out of his desire to remove the post in part by Kaplan, according to the people. Instead, the executives created an allowance that newsworthy political discourse would be taken into account when making decisions about whether posts violated community guidelines.
That allowance was not formally written into the policies, even though it informed ad hoc decision-making about political speech for the next several years, according to the people. When a formal newsworthiness policy was announced in October 2016, in a blog post by Kaplan, the company did not discuss Trump’s role in shaping it.
In an interview, Bickert said the company ultimately made a call to maintain Trump’s Muslim ban video because executives interpreted Trump’s comment to mean that the then-candidate was not speaking about all Muslims, but rather advocating for a policy position on immigration as part of a newsworthy political debate. She said she did not recall the document where the options were presented.
Facebook’s Bounds added that the “newsworthiness” policy was added in 2016 after content reviewers removed a photo of a naked girl fleeing a napalm attack during the Vietnam War. “Our goal was to recognize the essential public benefit of preserving content that in other contexts wouldn’t be allowed,” Bounds said. “In the case of elected officials, it also ensures that they will be held to account for their words,” so that people can judge for themselves.
In spring of 2016, Zuckerberg was also talked out of his desire to write a post specifically condemning Trump for his calls to build a wall between the United States and Mexico, after advisers in Washington warned it could look like choosing sides, according to Dex Torricke-Barton, one of Zuckerberg’s former speechwriters.
The political speech carveout ended up setting the stage for how the company would handle not only Trump, but populist leaders around the world who have posted content that test these boundaries, such as Rodrigo Duterte in the Philippines, Jair Bolsonaro in Brazil and Narendra Modi in India.
“Though [Facebook] has cracked down on misinformation, the most problematic influencers are politicians,” said Claire Wardle, U.S. director of First Draft, an organization dedicated to fighting misinformation that has a partnership with Facebook. “You can do all the fact checking in the world, but these influencers have a disproportionate impact.”
Trump presented a unique challenge, she added. “Until then, no one would have considered a president who would have said those things.”
Protecting the right
After the election, it became clear Russia had used social media to sow disinformation. Facebook soon after became a frequent target of the president’s ire. He tweeted that the social media giant was “anti-Trump” and trying to undermine his victory.
At the same time, GOP leaders stepped up criticism that platforms such as Facebook and Twitter, with leadership ranks full of liberals, sought to limit the reach of right-leaning voices.
“There’s no credible research supporting Trump’s claim that social platforms suppress conservative content, but he still succeeded in getting them to revise their rules for him,” said former Facebook spokesman Nu Wexler, who left the company in 2018.
As Facebook scrambled to tackle foreign interference and misinformation, its executives in the nation’s capital argued that caution and deference was necessary to survive the new political environment, according to three people familiar with the company’s thinking.
Facebook’s security engineers in December 2016 presented findings from a broad internal investigation, known as Project P, to senior leadership on how false and misleading news reports spread so virally during the election. When Facebook’s security team highlighted dozens of pages that had peddled false news reports, senior leaders in Washington, including Kaplan, opposed shutting them down immediately, arguing that doing so would disproportionately impact conservatives, according to people familiar with the company’s thinking. Ultimately, the company shut down far fewer pages than were originally proposed while it began developing a policy to handle these issues.
A year later, Facebook considered how to overhaul its scrolling news feed, the homepage screen most users see when they open the site. As part of the change to help limit misinformation, it changed its news feed algorithm to focus more on posts by friends and family versus publishers.
In meetings about the change, Kaplan questioned whether the revamped algorithm would hurt right-leaning publishers more than others, according to three people familiar with the company’s thinking who spoke on the condition of anonymity for fear of retribution. When the data showed it would — conservative leaning outlets were pushing more content that violated its policies, the company had found — he successfully pushed for changes to make the new algorithm to be what he considered more evenhanded in its impact, the people said.

Isolated and divided
With the 2020 election on the horizon, Facebook and Zuckerberg’s hands-off approach to free speech was leaving it increasingly isolated in Silicon Valley.
In May 2019, Zuckerberg, citing free speech, refused to take down a doctored video of House Speaker Nancy Pelosi (D-Calif.) that made her appear drunk.
That summer, company leaders held a meeting to revisit its newsworthiness exception, which until then had been determined on a case-by-case basis, with the most controversial calls made by Zuckerberg. Internally, some were unclear how far that leeway extended, according to two people.
Clegg, the company’s new head of global affairs and communications and a former British deputy prime minister, announced the outcome of that meeting at a speech in Washington in September 2019. Aside from speech that causes violence or real-world harm, Facebook would allow politicians to express themselves virtually unchecked on social media. Facebook’s network of independent fact-checkers, which had been established as a key part of the company’s response to disinformation, would not evaluate their claims and the community guidelines would largely not apply to politicians.
Facebook did not want to be an arbiter of truth in political debate, he said, echoing Zuckerberg’s long-standing position.
The speech angered some employees, triggering more than 250 of them to sign a petition disagreeing with the decision because they thought it gave politicians a pass.
One former executive, Yael Eisenstat, who worked to improve the political ads process, wrote in The Post that the controversy was “the biggest test of whether [Facebook] will ever truly put society and democracy ahead of profit and ideology.”
She said that she routinely experienced how the company’s efforts at integrity were often undermined by “the few voices who ultimately decided the company’s overall direction.”
Meanwhile, in October, as Facebook faced more potential regulation and political troubles, Zuckerberg and his wife Priscilla Chan went to the White House for a private dinner with Trump, a part of the CEO’s effort to cultivate personal relationships in Washington.
Tweetstorm
As the pandemic and civil unrest dominated the first half of this year, Trump continued to turn to social media platforms to spread misinformation. He touted the unproven drug hydroxychloroquine as a possible cure for the coronavirus and claimed without evidence that the left-wing antifa movement was behind the violence at George Floyd protests.
Meanwhile, Facebook employees began challenging the company’s decisions.

Two months before Trump’s “looting, shooting” post, the Brazilian president posted about the country’s indigenous population, saying, “Indians are undoubtedly changing. They are increasingly becoming human beings just like us.”
Thiel, the security engineer, and other employees argued internally that it violated the company’s internal guidelines against “dehumanizing speech.” They were referring to Zuckerberg’s own words while testifying before Congress in October in which he said dehumanizing speech “is the first step toward inciting” violence. In internal correspondence, Thiel was told that it didn’t qualify as racism — and may have even been a positive reference to integration.
Thiel quit in disgust.
In May, following years of internal debate of its own, Twitter chose to go in the opposite direction. It labeled two misleading tweets by Trump about mail-in ballots with a fact-check label.
Trump responded two days later with an executive order that could hurt social media companies by removing a key exception that limits their liability for content posted on their sites.
President Trump, with Attorney General William P. Barr, speaks in the Oval Office before signing an executive order related to regulating social media on May 28. (Pool/Photographer: /Getty Images)
The next day, Trump tweeted about the Minnesota protests. Twitter quickly labeled the tweet for violating rules about glorifying violence, and Snapchat stopped promoting Trump’s account the following week. YouTube told The Post that it holds politicians to the same standards as everyone else.
Facebook, on the other hand, chose to haggle with the White House, asking for a deletion or a change, said the people. Axios first reported the call, which Facebook’s Bounds confirmed to The Post.
As employees raged on internal message boards and externally on Twitter, Zuckerberg told workers that Facebook’s policies might change again in light of Trump’s post. The company had rules allowing for “state use of force,” he said, but they were vague and didn’t encompass the possibility that such pronouncements could signal harmful aggression. Bickert’s team planned a series of policy meetings for the weeks ahead.
In June, Facebook removed a swath of Trump campaign ads with Nazi symbolism, after an initial internal assessment that found the ads did not violate the company’s polices, according to documents viewed by The Post. In meetings, senior executives argued that not removing them would be perceived as pandering too much to the president, according to a person familiar with the discussions.
Last week, the advertiser boycott picked up steam. Hershey, Verizon, Unilever, Coca-Cola and others said they were temporarily pulling ads.
On Friday, Zuckerberg told employees in a live-streamed town hall that he was changing the company’s policy to label problematic newsworthy content that violated the company’s policies as Twitter does, a major concession amid the rising tide of criticism. He also said in the most explicit language ever that the company would remove posts by politicians that incite violence and suppress voting. Still, civil rights leaders said his assertions didn’t go far enough.

“There are no exceptions for politicians in any of the policies that I’m announcing today,” Zuckerberg said.

"""

# %%
doc = text

# %%
processor = spacy.load('en_core_web_sm')

# %%
processed_text = processor(text)
processed_text
# Out:
#  Zuckerberg once wanted to sanction Trump. Then Facebook wrote rules that accommodated him.
# Starting as early as 2015, Facebook executives started crafting exceptions for the then-candidate that transformed the world’s information battlefield for years to come.
#
# Hours after President Trump’s incendiary post last month about sending the military to the Minnesota protests, Trump called Facebook chief executive Mark Zuckerberg.
# The post put the company in a difficult position, Zuckerberg told Trump, according to people familiar with the discussions. The same message was hidden by Twitter, the strongest action ever taken against a presidential post.
# To Facebook’s executives in Washington, the post didn’t appear to violate its policies, which allows leaders to post about government use of force if the message is intended to warn the public — but it came right up to the line. The deputies had already contacted the White House earlier in the day with an urgent plea to tweak the language of the post or simply delete it, the people said.
# Eventually, Trump posted again, saying his comments were supposed to be a warning after all. Zuckerberg then went online to explain his rationale for keeping the post up, noting that Trump’s subsequent explanation helped him make his decision.
# The frenzied push-pull was just the latest incident in a five-year struggle by Facebook to accommodate the boundary-busting ways of Trump. The president has not changed his rhetoric since he was a candidate, but the company has continually altered its policies and its products in ways certain to outlast his presidency.
# Bowing to pressure, Facebook will start labeling violating posts from politicians. But critics say it’s not enough.
# Facebook has constrained its efforts against false and misleading news, adopted a policy explicitly allowing politicians to lie, and even altered its news feed algorithm to neutralize claims that it was biased against conservative publishers, according to more than a dozen former and current employees and previously unreported documents obtained by The Washington Post. One of the documents shows it began as far back as 2015, when as a candidate Trump posted a video calling for a ban of Muslims entering the United States. Facebook’s executives declined to remove it, setting in motion an exception for political discourse.
# The concessions to Trump have led to a transformation of the world’s information battlefield. They paved the way for a growing list of digitally savvy politicians to repeatedly push out misinformation and incendiary political language to billions of people. It has complicated the public understanding of major events such as the pandemic and the protest movement, as well as contributed to polarization.
# And as Trump grew in power, the fear of his wrath pushed Facebook into more deferential behavior toward its growing number of right-leaning users, tilting the balance of news people see on the network, according to the current and former employees.
# Facebook is now confronting a mounting advertiser boycott that has pushed down its stock price as companies demand stricter policies against hate speech. Starbucks became the latest on Sunday to say it would hit pause on social media advertising.
# Facebook is also facing a slow-burning crisis of morale, with more than 5,000 employees denouncing the company’s decision to leave Trump’s post that said, “when the looting starts, the shooting starts,” up.
#
# Bowing to those pressures on Friday, Zuckerberg announced a rash of new policies aimed at better policing content on the site. That includes affixing labels on posts that violate hate speech or other policies — even on those from political leaders.
# But the company said the post wouldn’t have qualified.
# As the United States heads into another presidential election while facing a pandemic and civil unrest, the latitude given to Trump may afford him a potential advantage. In recent months, he has used Facebook and other platforms to tout misleading information about coronavirus cures, election fraud and the motives of protesters, frequently targeting a left-wing movement as a cause of violence without citing evidence.
# It also places Facebook in growing conflict with its counterparts in Silicon Valley. Twitter has labeled several presidential tweets as abusive and misleading, and social media platform Snapchat curtailed the reach of the president’s account.
# “The value of being in favor with people in power outweighs almost every other concern for Facebook,” said David Thiel, a Facebook security engineer who resigned in March after his colleagues refused to remove a post he believed constituted “dehumanizing speech” by Brazil’s president.
# Facebook contends the use of incendiary populist language predates social media. Nick Clegg, Facebook’s vice president for global affairs and communications, said in a statement that populism wasn’t invented in Silicon Valley, pointing to centuries of political history before social media companies’ existence.
# Nick Clegg, Facebook's vice president of global affairs, said that populism wasn’t invented in Silicon Valley. (Kirsty Wigglesworth/AP)
# “From the Arab Spring to local candidates challenging political incumbents, social media has also helped to open up politics, not favor one side over the other,” Clegg added. “Studies have shown the drivers of populism are complex and cannot be reduced to the use of social media, in fact political polarization has fallen in many countries with high internet use.”
# Facebook declined to make Zuckerberg available for an interview, although it pointed out that Zuckerberg opposed Trump when his Muslim immigration ban went into effect. The White House declined to comment.
# Zuckerberg talks frequently about making choices that stand the test of time, preserving the values of Facebook and subsidiaries WhatsApp and Instagram for all of its nearly 3 billion monthly users for many years into the future — even when those decisions are unpopular or controversial.
# At one point, however, he wanted a different approach to Trump.
# Setting the stage
# Before the 2016 election, the company largely saw its role in politics as courting political leaders to buy ads and broadcast their views, according to people familiar with the company’s thinking.
#
# But that started to change in 2015, as Trump’s candidacy picked up speed. In December of that year, he posted a video in which he said he wanted to ban all Muslims from entering the United States. The video went viral on Facebook and was an early indication of the tone of his candidacy.
# Outrage over the video led to a companywide town hall, in which employees decried the video as hate speech, in violation of the company’s policies. And in meetings about the issue, senior leaders and policy experts overwhelmingly said they felt that the video was hate speech, according to three former employees, who spoke on the condition of anonymity for fear of retribution. Zuckerberg expressed in meetings that he was personally disgusted by it and wanted it removed, the people said. Some of these details were previously reported.
# At one of the meetings, Monika Bickert, Facebook’s vice president for policy, drafted a document to address the video and shared it with leaders including Zuckerberg’s top deputy COO Sheryl Sandberg and Vice President of Global Policy Joel Kaplan, the company’s most prominent Republican.
# The document, which is previously unreported and obtained by The Post, weighed four options. They included removing the post for hate speech violations, making a one-time exception for it, creating a broad exemption for political discourse and even weakening the company’s community guidelines for everyone, allowing comments such as “No blacks allowed” and “Get the gays out of San Francisco.”
# Facebook spokesman Tucker Bounds said the latter option was never seriously considered.
# The document also listed possible “PR Risks” for each. For example, lowering the standards overall would raise questions such as, “Would Facebook have provided a platform for Hitler?” Bickert wrote. A carveout for political speech across the board, on the other hand, risked opening the floodgates for even more hateful “copycat” comments.
# Ultimately, Zuckerberg was talked out of his desire to remove the post in part by Kaplan, according to the people. Instead, the executives created an allowance that newsworthy political discourse would be taken into account when making decisions about whether posts violated community guidelines.
# That allowance was not formally written into the policies, even though it informed ad hoc decision-making about political speech for the next several years, according to the people. When a formal newsworthiness policy was announced in October 2016, in a blog post by Kaplan, the company did not discuss Trump’s role in shaping it.
# In an interview, Bickert said the company ultimately made a call to maintain Trump’s Muslim ban video because executives interpreted Trump’s comment to mean that the then-candidate was not speaking about all Muslims, but rather advocating for a policy position on immigration as part of a newsworthy political debate. She said she did not recall the document where the options were presented.
# Facebook’s Bounds added that the “newsworthiness” policy was added in 2016 after content reviewers removed a photo of a naked girl fleeing a napalm attack during the Vietnam War. “Our goal was to recognize the essential public benefit of preserving content that in other contexts wouldn’t be allowed,” Bounds said. “In the case of elected officials, it also ensures that they will be held to account for their words,” so that people can judge for themselves.
# In spring of 2016, Zuckerberg was also talked out of his desire to write a post specifically condemning Trump for his calls to build a wall between the United States and Mexico, after advisers in Washington warned it could look like choosing sides, according to Dex Torricke-Barton, one of Zuckerberg’s former speechwriters.
# The political speech carveout ended up setting the stage for how the company would handle not only Trump, but populist leaders around the world who have posted content that test these boundaries, such as Rodrigo Duterte in the Philippines, Jair Bolsonaro in Brazil and Narendra Modi in India.
# “Though [Facebook] has cracked down on misinformation, the most problematic influencers are politicians,” said Claire Wardle, U.S. director of First Draft, an organization dedicated to fighting misinformation that has a partnership with Facebook. “You can do all the fact checking in the world, but these influencers have a disproportionate impact.”
# Trump presented a unique challenge, she added. “Until then, no one would have considered a president who would have said those things.”
# Protecting the right
# After the election, it became clear Russia had used social media to sow disinformation. Facebook soon after became a frequent target of the president’s ire. He tweeted that the social media giant was “anti-Trump” and trying to undermine his victory.
# At the same time, GOP leaders stepped up criticism that platforms such as Facebook and Twitter, with leadership ranks full of liberals, sought to limit the reach of right-leaning voices.
# “There’s no credible research supporting Trump’s claim that social platforms suppress conservative content, but he still succeeded in getting them to revise their rules for him,” said former Facebook spokesman Nu Wexler, who left the company in 2018.
# As Facebook scrambled to tackle foreign interference and misinformation, its executives in the nation’s capital argued that caution and deference was necessary to survive the new political environment, according to three people familiar with the company’s thinking.
# Facebook’s security engineers in December 2016 presented findings from a broad internal investigation, known as Project P, to senior leadership on how false and misleading news reports spread so virally during the election. When Facebook’s security team highlighted dozens of pages that had peddled false news reports, senior leaders in Washington, including Kaplan, opposed shutting them down immediately, arguing that doing so would disproportionately impact conservatives, according to people familiar with the company’s thinking. Ultimately, the company shut down far fewer pages than were originally proposed while it began developing a policy to handle these issues.
# A year later, Facebook considered how to overhaul its scrolling news feed, the homepage screen most users see when they open the site. As part of the change to help limit misinformation, it changed its news feed algorithm to focus more on posts by friends and family versus publishers.
# In meetings about the change, Kaplan questioned whether the revamped algorithm would hurt right-leaning publishers more than others, according to three people familiar with the company’s thinking who spoke on the condition of anonymity for fear of retribution. When the data showed it would — conservative leaning outlets were pushing more content that violated its policies, the company had found — he successfully pushed for changes to make the new algorithm to be what he considered more evenhanded in its impact, the people said.
#
# Isolated and divided
# With the 2020 election on the horizon, Facebook and Zuckerberg’s hands-off approach to free speech was leaving it increasingly isolated in Silicon Valley.
# In May 2019, Zuckerberg, citing free speech, refused to take down a doctored video of House Speaker Nancy Pelosi (D-Calif.) that made her appear drunk.
# That summer, company leaders held a meeting to revisit its newsworthiness exception, which until then had been determined on a case-by-case basis, with the most controversial calls made by Zuckerberg. Internally, some were unclear how far that leeway extended, according to two people.
# Clegg, the company’s new head of global affairs and communications and a former British deputy prime minister, announced the outcome of that meeting at a speech in Washington in September 2019. Aside from speech that causes violence or real-world harm, Facebook would allow politicians to express themselves virtually unchecked on social media. Facebook’s network of independent fact-checkers, which had been established as a key part of the company’s response to disinformation, would not evaluate their claims and the community guidelines would largely not apply to politicians.
# Facebook did not want to be an arbiter of truth in political debate, he said, echoing Zuckerberg’s long-standing position.
# The speech angered some employees, triggering more than 250 of them to sign a petition disagreeing with the decision because they thought it gave politicians a pass.
# One former executive, Yael Eisenstat, who worked to improve the political ads process, wrote in The Post that the controversy was “the biggest test of whether [Facebook] will ever truly put society and democracy ahead of profit and ideology.”
# She said that she routinely experienced how the company’s efforts at integrity were often undermined by “the few voices who ultimately decided the company’s overall direction.”
# Meanwhile, in October, as Facebook faced more potential regulation and political troubles, Zuckerberg and his wife Priscilla Chan went to the White House for a private dinner with Trump, a part of the CEO’s effort to cultivate personal relationships in Washington.
# Tweetstorm
# As the pandemic and civil unrest dominated the first half of this year, Trump continued to turn to social media platforms to spread misinformation. He touted the unproven drug hydroxychloroquine as a possible cure for the coronavirus and claimed without evidence that the left-wing antifa movement was behind the violence at George Floyd protests.
# Meanwhile, Facebook employees began challenging the company’s decisions.
#
# Two months before Trump’s “looting, shooting” post, the Brazilian president posted about the country’s indigenous population, saying, “Indians are undoubtedly changing. They are increasingly becoming human beings just like us.”
# Thiel, the security engineer, and other employees argued internally that it violated the company’s internal guidelines against “dehumanizing speech.” They were referring to Zuckerberg’s own words while testifying before Congress in October in which he said dehumanizing speech “is the first step toward inciting” violence. In internal correspondence, Thiel was told that it didn’t qualify as racism — and may have even been a positive reference to integration.
# Thiel quit in disgust.
# In May, following years of internal debate of its own, Twitter chose to go in the opposite direction. It labeled two misleading tweets by Trump about mail-in ballots with a fact-check label.
# Trump responded two days later with an executive order that could hurt social media companies by removing a key exception that limits their liability for content posted on their sites.
# President Trump, with Attorney General William P. Barr, speaks in the Oval Office before signing an executive order related to regulating social media on May 28. (Pool/Photographer: /Getty Images)
# The next day, Trump tweeted about the Minnesota protests. Twitter quickly labeled the tweet for violating rules about glorifying violence, and Snapchat stopped promoting Trump’s account the following week. YouTube told The Post that it holds politicians to the same standards as everyone else.
# Facebook, on the other hand, chose to haggle with the White House, asking for a deletion or a change, said the people. Axios first reported the call, which Facebook’s Bounds confirmed to The Post.
# As employees raged on internal message boards and externally on Twitter, Zuckerberg told workers that Facebook’s policies might change again in light of Trump’s post. The company had rules allowing for “state use of force,” he said, but they were vague and didn’t encompass the possibility that such pronouncements could signal harmful aggression. Bickert’s team planned a series of policy meetings for the weeks ahead.
# In June, Facebook removed a swath of Trump campaign ads with Nazi symbolism, after an initial internal assessment that found the ads did not violate the company’s polices, according to documents viewed by The Post. In meetings, senior executives argued that not removing them would be perceived as pandering too much to the president, according to a person familiar with the discussions.
# Last week, the advertiser boycott picked up steam. Hershey, Verizon, Unilever, Coca-Cola and others said they were temporarily pulling ads.
# On Friday, Zuckerberg told employees in a live-streamed town hall that he was changing the company’s policy to label problematic newsworthy content that violated the company’s policies as Twitter does, a major concession amid the rising tide of criticism. He also said in the most explicit language ever that the company would remove posts by politicians that incite violence and suppress voting. Still, civil rights leaders said his assertions didn’t go far enough.
#
# “There are no exceptions for politicians in any of the policies that I’m announcing today,” Zuckerberg said.

# %% [markdown]
# ### 1. Show the most common words in the article.

# %%
import re
from collections import Counter

# %%
words = [token.text for token in processed_text if token.is_stop != True 
         and token.is_punct !=True]
lower_words = [word.lower() for word in words]

# %%
Counter(lower_words).most_common(10)
# Out:
# [('\n', 67),
#  ('facebook', 45),
#  ('trump', 33),
#  ('company', 30),
#  ('said', 26),
#  ('zuckerberg', 22),
#  ('post', 22),
#  ('political', 17),
#  ('people', 16),
#  ('speech', 16)]

# %% [markdown]
# ### 2. Show the most common words under a part of speech. (i.e. NOUN: {'Bob':12, 'Alice':4,})

# %%
nouns = [token.text for token in processed_text if token.is_stop != True 
         and token.is_punct !=True and token.pos_ =='NOUN']
print(Counter(nouns).most_common(15))
# Out:
# [('company', 30), ('people', 16), ('speech', 16), ('post', 15), ('media', 12), ('policies', 11), ('leaders', 10), ('president', 10), ('politicians', 10), ('employees', 10), ('policy', 9), ('video', 9), ('content', 8), ('executives', 7), ('news', 7)]

# %%
verbs = [token.text for token in processed_text if token.is_stop != True 
         and token.is_punct !=True and token.pos_ =='VERB']
print(Counter(verbs).most_common(15))
# Out:
# [('said', 26), ('according', 14), ('posted', 6), ('told', 5), ('wanted', 4), ('went', 4), ('remove', 4), ('leaning', 4), ('added', 4), ('making', 4), ('considered', 4), ('violated', 4), ('wrote', 3), ('violate', 3), ('allowing', 3)]

# %%
adj = [token.text for token in processed_text if token.is_stop != True 
         and token.is_punct !=True and token.pos_ =='ADJ']
print(Counter(adj).most_common(15))
# Out:
# [('political', 17), ('social', 13), ('familiar', 6), ('internal', 6), ('new', 4), ('senior', 4), ('incendiary', 3), ('presidential', 3), ('false', 3), ('misleading', 3), ('conservative', 3), ('civil', 3), ('dehumanizing', 3), ('global', 3), ('newsworthy', 3)]

# %%
adv = [token.text for token in processed_text if token.is_stop != True 
         and token.is_punct !=True and token.pos_ =='ADV']
print(Counter(adv).most_common(15))
# Out:
# [('far', 4), ('previously', 3), ('right', 2), ('frequently', 2), ('largely', 2), ('Ultimately', 2), ('ultimately', 2), ('later', 2), ('increasingly', 2), ('ahead', 2), ('early', 1), ('earlier', 1), ('simply', 1), ('Eventually', 1), ('online', 1)]

# %% [markdown]
# ### 3. Find a subject/object relationship through the dependency parser in any sentence.

# %%
def pr_tree(word, level):
    if word.is_punct:
        return
    for child in word.lefts:
        pr_tree(child, level+1)
    print('\t'* level + word.text + ' - ' + word.dep_)
    for child in word.rights:
        pr_tree(child, level+1)

# %%
for sentence in processed_text.sents:
    pr_tree(sentence.root, 0)
    print('-------------------------------------------')
# Out:
# 		  -
# 	Zuckerberg - nsubj
# 	once - advmod
# wanted - ROOT
# 		to - aux
# 	sanction - xcomp
# 		Trump - dobj
# -------------------------------------------
# 	Then - advmod
# 	Facebook - nsubj
# wrote - ROOT
# 	rules - dobj
# 			that - nsubj
# 		accommodated - relcl
# 			him - dobj
# -------------------------------------------
# 	Starting - advcl
# 			as - advmod
# 		early - advmod
# 			as - prep
# 				2015 - pobj
# 		Facebook - compound
# 	executives - nsubj
# started - ROOT
# 	crafting - xcomp
# 		exceptions - dobj
# 			for - prep
# 					the - det
# 					then - advmod
# 				candidate - pobj
# 						that - nsubj
# 					transformed - relcl
# 							the - det
# 						world - dobj
# 	’s - punct
# 		information - nsubj
# 	battlefield - advcl
# 		for - prep
# 			years - pobj
# 					to - aux
# 				come - relcl
# -------------------------------------------
# 	Hours - npadvmod
# 	after - prep
# 				President - compound
# 			Trump - poss
# 				’s - case
# 			incendiary - amod
# 		post - pobj
# 				last - amod
# 			month - npadvmod
# 			about - prep
# 				sending - pcomp
# 						the - det
# 					military - dobj
# 					to - prep
# 							the - det
# 							Minnesota - compound
# 						protests - pobj
# 	Trump - nsubj
# called - ROOT
# 			Facebook - compound
# 			chief - amod
# 		executive - compound
# 		Mark - compound
# 	Zuckerberg - oprd
# -------------------------------------------
# 			The - det
# 		post - nsubj
# 	put - ccomp
# 			the - det
# 		company - dobj
# 		in - prep
# 				a - det
# 				difficult - amod
# 			position - pobj
# 	Zuckerberg - nsubj
# told - ROOT
# 	Trump - dobj
# 	according - prep
# 		to - prep
# 			people - pobj
# 				familiar - amod
# 					with - prep
# 							the - det
# 						discussions - pobj
# -------------------------------------------
# 		The - det
# 		same - amod
# 	message - nsubjpass
# 	was - auxpass
# hidden - ROOT
# 	by - agent
# 		Twitter - pobj
# 				the - det
# 				strongest - amod
# 			action - appos
# 					ever - advmod
# 				taken - acl
# 					against - prep
# 							a - det
# 							presidential - amod
# 						post - pobj
# -------------------------------------------
# 	To - prep
# 		Facebook - pobj
# 		’s - pobj
# 		executives - pobj
# 			in - prep
# 				Washington - pobj
# 		the - det
# 	post - nsubj
# 	did - aux
# 	n’t - neg
# appear - ROOT
# 		to - aux
# 	violate - xcomp
# 			its - poss
# 		policies - dobj
# 				which - nsubj
# 			allows - relcl
# 					leaders - nsubj
# 					to - aux
# 				post - ccomp
# 					about - prep
# 							government - compound
# 						use - pobj
# 							of - prep
# 								force - pobj
# 						if - mark
# 							the - det
# 						message - nsubjpass
# 						is - auxpass
# 					intended - advcl
# 							to - aux
# 						warn - xcomp
# 								the - det
# 							public - dobj
# 	but - cc
# 		it - nsubj
# 	came - conj
# 			right - advmod
# 		up - prep
# 			to - prep
# 					the - det
# 				line - pobj
# -------------------------------------------
# 			The - det
# 		deputies - nsubj
# 		had - aux
# 		already - advmod
# 	contacted - ccomp
# 			the - det
# 			White - compound
# 		House - dobj
# 		earlier - advmod
# 			in - prep
# 					the - det
# 				day - pobj
# 		with - prep
# 				an - det
# 				urgent - amod
# 			plea - pobj
# 			to - aux
# 		tweak - advcl
# 				the - det
# 			language - dobj
# 				of - prep
# 						the - det
# 					post - pobj
# 			or - cc
# 				simply - advmod
# 			delete - conj
# 				it - dobj
# 		the - det
# 	people - nsubj
# said - ROOT
# -------------------------------------------
# 	Eventually - advmod
# 	Trump - nsubj
# posted - ROOT
# 	again - advmod
# 	saying - advcl
# 				his - poss
# 			comments - nsubjpass
# 			were - auxpass
# 		supposed - ccomp
# 				to - aux
# 			be - xcomp
# 					a - det
# 				warning - attr
# 						after - advmod
# 					all - advmod
# -------------------------------------------
# 	Zuckerberg - nsubj
# 	then - advmod
# went - ROOT
# 	online - advmod
# 		to - aux
# 	explain - advcl
# 			his - poss
# 		rationale - dobj
# 		for - prep
# 			keeping - pcomp
# 					the - det
# 				post - dobj
# 				up - prt
# 	noting - advcl
# 			that - mark
# 				Trump - poss
# 					’s - case
# 				subsequent - amod
# 			explanation - nsubj
# 		helped - ccomp
# 				him - nsubj
# 			make - ccomp
# 					his - poss
# 				decision - dobj
# -------------------------------------------
# 		The - det
# 		frenzied - amod
# 		push - compound
# 	pull - nsubj
# was - ROOT
# 		just - advmod
# 		the - det
# 		latest - amod
# 	incident - attr
# 		in - prep
# 				a - det
# 					five - nummod
# 				year - compound
# 			struggle - pobj
# 				by - prep
# 					Facebook - pobj
# 			to - aux
# 		accommodate - acl
# 				the - det
# 					boundary - npadvmod
# 				busting - amod
# 			ways - dobj
# 				of - prep
# 					Trump - pobj
# -------------------------------------------
# 		The - det
# 	president - nsubj
# 	has - aux
# 	not - neg
# changed - ROOT
# 		his - poss
# 	rhetoric - dobj
# 		since - mark
# 		he - nsubj
# 	was - advcl
# 			a - det
# 		candidate - attr
# 	but - cc
# 			the - det
# 		company - nsubj
# 		has - aux
# 		continually - advmod
# 	altered - conj
# 			its - poss
# 		policies - dobj
# 			and - cc
# 				its - poss
# 			products - conj
# 		in - prep
# 			ways - pobj
# 				certain - amod
# 						to - aux
# 					outlast - xcomp
# 							his - poss
# 						presidency - dobj
# -------------------------------------------
# 	Bowing - advcl
# 		to - prep
# 			pressure - pobj
# 	Facebook - nsubj
# 	will - aux
# start - ROOT
# 	labeling - xcomp
# 		violating - xcomp
# 			posts - dobj
# 				from - prep
# 					politicians - pobj
# -------------------------------------------
# 	But - cc
# 	critics - nsubj
# say - ROOT
# 	it - dobj
# 	’s - ccomp
# 		not - neg
# 	enough - ccomp
# -------------------------------------------
# 	Facebook - nsubj
# 	has - aux
# constrained - ROOT
# 		its - poss
# 	efforts - dobj
# 		against - prep
# 				false - amod
# 					and - cc
# 					misleading - conj
# 			news - pobj
# 	adopted - conj
# 			a - det
# 		policy - dobj
# 			explicitly - advmod
# 		allowing - advcl
# 				politicians - nsubj
# 				to - aux
# 			lie - ccomp
# 		and - cc
# 			even - advmod
# 		altered - conj
# 				its - poss
# 					news - compound
# 				feed - compound
# 			algorithm - dobj
# 				to - aux
# 			neutralize - advcl
# 				claims - dobj
# 						that - mark
# 						it - nsubjpass
# 						was - auxpass
# 					biased - acl
# 						against - prep
# 								conservative - amod
# 							publishers - pobj
# 		according - prep
# 			to - prep
# 						more - amod
# 						than - quantmod
# 						a - quantmod
# 					dozen - nummod
# 					former - amod
# 						and - cc
# 						current - conj
# 				employees - pobj
# 					and - cc
# 							previously - advmod
# 						unreported - amod
# 					documents - conj
# 						obtained - acl
# 							by - agent
# 									The - det
# 									Washington - compound
# 								Post - pobj
# -------------------------------------------
# 	One - nsubj
# 		of - prep
# 				the - det
# 			documents - pobj
# shows - ROOT
# 		it - nsubj
# 	began - ccomp
# 				as - advmod
# 			far - advmod
# 		back - advmod
# 			as - prep
# 				2015 - pobj
# 			when - advmod
# 			as - mark
# 					a - det
# 				candidate - compound
# 			Trump - nsubj
# 		posted - advcl
# 				a - det
# 			video - dobj
# 				calling - acl
# 					for - prep
# 							a - det
# 						ban - pobj
# 							of - prep
# 								Muslims - pobj
# 									entering - acl
# 											the - det
# 											United - compound
# 										States - dobj
# -------------------------------------------
# 		Facebook - nmod
# 			’s - punct
# 	executives - nsubj
# declined - ROOT
# 		to - aux
# 	remove - xcomp
# 		it - dobj
# 		setting - advcl
# 			in - prep
# 				motion - pobj
# 				an - det
# 			exception - dobj
# 				for - prep
# 						political - amod
# 					discourse - pobj
# -------------------------------------------
# 		The - det
# 	concessions - nsubj
# 		to - prep
# 			Trump - pobj
# 	have - aux
# led - ROOT
# 	to - prep
# 			a - det
# 		transformation - pobj
# 			of - prep
# 					the - det
# 				world - pobj
# 	’s - punct
# 		information - compound
# 	battlefield - advcl
# -------------------------------------------
# 	They - nsubj
# paved - ROOT
# 		the - det
# 	way - dobj
# 			for - mark
# 				a - det
# 				growing - amod
# 			list - nsubj
# 				of - prep
# 							digitally - advmod
# 						savvy - amod
# 					politicians - pobj
# 			to - aux
# 			repeatedly - advmod
# 		push - relcl
# 			out - prt
# 			misinformation - dobj
# 				and - cc
# 					incendiary - amod
# 					political - amod
# 				language - conj
# 			to - prep
# 				billions - pobj
# 					of - prep
# 						people - pobj
# -------------------------------------------
# 	It - nsubj
# 	has - aux
# complicated - ROOT
# 		the - det
# 		public - amod
# 	understanding - dobj
# 		of - prep
# 				major - amod
# 			events - pobj
# 					such - amod
# 				as - prep
# 						the - det
# 					pandemic - pobj
# 						and - cc
# 							the - det
# 							protest - compound
# 						movement - conj
# 			as - advmod
# 			well - advmod
# 		as - cc
# 		contributed - conj
# 			to - prep
# 				polarization - pobj
# -------------------------------------------
# 	And - cc
# 		as - mark
# 		Trump - nsubj
# 	grew - advcl
# 		in - prep
# 			power - pobj
# 		the - det
# 	fear - nsubj
# 		of - prep
# 				his - poss
# 			wrath - pobj
# pushed - ROOT
# 	Facebook - dobj
# 	into - prep
# 			more - amod
# 			deferential - amod
# 		behavior - pobj
# 			toward - prep
# 					its - poss
# 					growing - amod
# 				number - pobj
# 					of - prep
# 								right - advmod
# 							leaning - amod
# 						users - pobj
# 	tilting - advcl
# 			the - det
# 		balance - dobj
# 			of - prep
# 					news - compound
# 				people - nsubj
# 			see - relcl
# 				on - prep
# 						the - det
# 					network - pobj
# 		according - prep
# 			to - prep
# 					the - det
# 					current - amod
# 						and - cc
# 						former - conj
# 				employees - pobj
# -------------------------------------------
# 	Facebook - nsubj
# 	is - aux
# 	now - advmod
# confronting - ROOT
# 		a - det
# 		mounting - amod
# 		advertiser - compound
# 	boycott - dobj
# 			that - nsubj
# 			has - aux
# 		pushed - relcl
# 			down - prt
# 				its - poss
# 				stock - compound
# 			price - dobj
# 				as - mark
# 				companies - nsubj
# 			demand - advcl
# 					stricter - amod
# 				policies - dobj
# 					against - prep
# 							hate - compound
# 						speech - pobj
# -------------------------------------------
# 	Starbucks - nsubj
# became - ROOT
# 		the - det
# 	latest - attr
# 		on - prep
# 			Sunday - pobj
# 		to - aux
# 	say - advcl
# 			it - nsubj
# 			would - aux
# 		hit - ccomp
# 			pause - dobj
# 				on - prep
# 						social - amod
# 						media - compound
# 					advertising - pobj
# -------------------------------------------
# 	Facebook - nsubj
# 	is - aux
# 	also - advmod
# facing - ROOT
# 		a - det
# 			slow - advmod
# 		burning - amod
# 	crisis - dobj
# 		of - prep
# 			morale - pobj
# 	with - prep
# 					more - amod
# 					than - quantmod
# 				5,000 - nummod
# 			employees - nsubj
# 		denouncing - pcomp
# 				the - det
# 			company - dobj
# 			’s - punct
# 			decision - dobj
# 					to - aux
# 				leave - acl
# 					Trump - dobj
# 			’s - punct
# 			post - dobj
# 					that - nsubj
# 				said - relcl
# 							when - advmod
# 								the - det
# 							looting - nsubj
# 						starts - advcl
# 							the - det
# 						shooting - nsubj
# 					starts - ccomp
# 			up - prt
# -------------------------------------------
# 	Bowing - advcl
# 		to - prep
# 				those - det
# 			pressures - pobj
# 		on - prep
# 			Friday - pobj
# 	Zuckerberg - nsubj
# announced - ROOT
# 		a - det
# 	rash - dobj
# 		of - prep
# 				new - amod
# 			policies - pobj
# 				aimed - acl
# 					at - prep
# 							better - amod
# 							policing - amod
# 						content - pobj
# 							on - prep
# 									the - det
# 								site - pobj
# -------------------------------------------
# 	That - nsubj
# includes - ROOT
# 		affixing - amod
# 	labels - dobj
# 		on - prep
# 			posts - pobj
# 					that - nsubj
# 				violate - relcl
# 						hate - compound
# 					speech - dobj
# 						or - cc
# 							other - amod
# 						policies - conj
# 						even - advmod
# 					on - prep
# 						those - pobj
# 							from - prep
# 									political - amod
# 								leaders - pobj
# -------------------------------------------
# 	But - cc
# 		the - det
# 	company - nsubj
# said - ROOT
# 			the - det
# 		post - nsubj
# 		would - aux
# 		n’t - neg
# 	have - ccomp
# 		qualified - dobj
# -------------------------------------------
# 		As - mark
# 			the - det
# 			United - compound
# 		States - nsubj
# 	heads - advcl
# 		into - prep
# 				another - det
# 				presidential - amod
# 			election - pobj
# 		while - mark
# 	facing - advcl
# 			a - det
# 			pandemic - amod
# 				and - cc
# 				civil - conj
# 		unrest - dobj
# 		the - det
# 	latitude - nsubj
# 		given - acl
# 			to - dative
# 				Trump - pobj
# 	may - aux
# afford - ROOT
# 	him - dative
# 		a - det
# 		potential - amod
# 	advantage - dobj
# -------------------------------------------
# 	In - prep
# 			recent - amod
# 		months - pobj
# 	he - nsubj
# 	has - aux
# used - ROOT
# 	Facebook - dobj
# 		and - cc
# 			other - amod
# 		platforms - conj
# 		to - aux
# 	tout - xcomp
# 		misleading - xcomp
# 			information - dobj
# 				about - prep
# 						coronavirus - compound
# 					cures - pobj
# 							election - compound
# 						fraud - conj
# 							and - cc
# 								the - det
# 							motives - conj
# 								of - prep
# 									protesters - pobj
# 			frequently - advmod
# 		targeting - advcl
# 				a - det
# 					left - amod
# 				wing - amod
# 			movement - dobj
# 			as - prep
# 					a - det
# 				cause - pobj
# 					of - prep
# 						violence - pobj
# 					without - prep
# 						citing - pcomp
# 							evidence - dobj
# -------------------------------------------
# 	It - nsubj
# 	also - advmod
# places - ROOT
# 	Facebook - dobj
# 	in - prep
# 			growing - amod
# 		conflict - pobj
# 			with - prep
# 					its - poss
# 				counterparts - pobj
# 					in - prep
# 							Silicon - compound
# 						Valley - pobj
# -------------------------------------------
# 	Twitter - nsubj
# 	has - aux
# labeled - ROOT
# 		several - amod
# 		presidential - amod
# 	tweets - dobj
# 	as - prep
# 		abusive - amod
# 			and - cc
# 			misleading - conj
# 	and - cc
# 					social - amod
# 				media - compound
# 			platform - compound
# 		Snapchat - nsubj
# 	curtailed - conj
# 			the - det
# 		reach - dobj
# 			of - prep
# 					the - det
# 				president - pobj
# 		’s - punct
# 		account - dobj
# -------------------------------------------
# 		The - det
# 	value - nsubj
# 		of - prep
# 			being - pcomp
# 				in - prep
# 					favor - pobj
# 				with - prep
# 					people - pobj
# 						in - prep
# 								power - compound
# 							outweighs - pobj
# 						almost - advmod
# 					every - nummod
# 					other - amod
# 				concern - attr
# 					for - prep
# 						Facebook - pobj
# said - ROOT
# 		David - compound
# 	Thiel - nsubj
# 			a - det
# 			Facebook - compound
# 			security - compound
# 		engineer - appos
# 				who - nsubj
# 			resigned - relcl
# 				in - prep
# 					March - pobj
# 					after - mark
# 						his - poss
# 					colleagues - nsubj
# 				refused - advcl
# 						to - aux
# 					remove - xcomp
# 							a - det
# 						post - dobj
# 								he - nsubj
# 							believed - relcl
# 	constituted - ccomp
# 			dehumanizing - amod
# 		speech - dobj
# 		by - agent
# 			Brazil - pobj
# 				’s - case
# 				president - appos
# -------------------------------------------
# 	Facebook - nsubj
# contends - ROOT
# 			the - det
# 		use - nsubj
# 			of - prep
# 					incendiary - amod
# 					populist - amod
# 				language - pobj
# 	predates - ccomp
# 			social - amod
# 		media - dobj
# -------------------------------------------
# 		Nick - compound
# 	Clegg - nsubj
# 			Facebook - poss
# 				’s - case
# 			vice - compound
# 		president - appos
# 			for - prep
# 					global - amod
# 				affairs - pobj
# 					and - cc
# 					communications - conj
# said - ROOT
# 	in - prep
# 			a - det
# 		statement - pobj
# 		that - mark
# 		populism - nsubjpass
# 		was - auxpass
# 		n’t - neg
# 	invented - ccomp
# 		in - prep
# 				Silicon - compound
# 			Valley - pobj
# 		pointing - advcl
# 			to - prep
# 				centuries - pobj
# 					of - prep
# 							political - amod
# 						history - pobj
# 			before - prep
# 						social - amod
# 						media - compound
# 					companies - poss
# 				existence - pobj
# -------------------------------------------
# 		Nick - compound
# 	Clegg - nsubj
# 			Facebook - poss
# 				's - case
# 			vice - compound
# 		president - appos
# 			of - prep
# 					global - amod
# 				affairs - pobj
# said - ROOT
# 		that - mark
# 		populism - nsubjpass
# 		was - auxpass
# 		n’t - neg
# 	invented - ccomp
# 		in - prep
# 				Silicon - compound
# 			Valley - pobj
# -------------------------------------------
# 	Kirsty - nmod
# 	Wigglesworth - nmod
# AP - ROOT
# -------------------------------------------
# 		From - prep
# 				the - det
# 				Arab - compound
# 			Spring - pobj
# 			to - prep
# 					local - amod
# 				candidates - pobj
# 					challenging - acl
# 							political - amod
# 						incumbents - dobj
# 			social - amod
# 		media - nsubj
# 		has - aux
# 		also - advmod
# 	helped - ccomp
# 			to - aux
# 		open - xcomp
# 			up - prt
# 			politics - dobj
# 				not - neg
# 			favor - dep
# 					one - nummod
# 				side - dobj
# 				over - prep
# 						the - det
# 					other - pobj
# 	Clegg - nsubj
# added - ROOT
# -------------------------------------------
# 		Studies - nsubj
# 		have - aux
# 	shown - ccomp
# 				the - det
# 			drivers - nsubj
# 				of - prep
# 					populism - pobj
# 		are - ccomp
# 			complex - acomp
# 			and - cc
# 				can - aux
# 				not - neg
# 				be - auxpass
# 			reduced - conj
# 				to - prep
# 						the - det
# 					use - pobj
# 						of - prep
# 								social - amod
# 							media - pobj
# 	in - prep
# 		fact - pobj
# 		political - amod
# 	polarization - nsubj
# 	has - aux
# fallen - ROOT
# 	in - prep
# 			many - amod
# 		countries - pobj
# 			with - prep
# 					high - amod
# 					internet - compound
# 				use - pobj
# -------------------------------------------
# 	Facebook - nsubj
# declined - ROOT
# 		to - aux
# 	make - xcomp
# 			Zuckerberg - nsubj
# 		available - ccomp
# 			for - prep
# 					an - det
# 				interview - pobj
# 		although - mark
# 		it - nsubj
# 	pointed - advcl
# 		out - prt
# 			that - mark
# 			Zuckerberg - nsubj
# 		opposed - ccomp
# 			Trump - dobj
# 				when - advmod
# 					his - poss
# 					Muslim - amod
# 					immigration - compound
# 				ban - nsubj
# 			went - advcl
# 				into - prep
# 					effect - pobj
# -------------------------------------------
# 		The - det
# 		White - compound
# 	House - nsubj
# declined - ROOT
# 		to - aux
# 	comment - xcomp
# -------------------------------------------
# 	Zuckerberg - compound
# talks - ROOT
# 	frequently - advmod
# 	about - prep
# 		making - pcomp
# 			choices - dobj
# 					that - nsubj
# 				stand - relcl
# 						the - det
# 					test - dobj
# 						of - prep
# 							time - pobj
# 			preserving - ccomp
# 					the - det
# 				values - dobj
# 					of - prep
# 						Facebook - pobj
# 							and - cc
# 							subsidiaries - conj
# 							WhatsApp - conj
# 								and - cc
# 								Instagram - conj
# 				for - prep
# 					all - pobj
# 						of - prep
# 								its - poss
# 									nearly - advmod
# 									3 - compound
# 								billion - nummod
# 								monthly - amod
# 							users - pobj
# 				for - prep
# 						many - amod
# 					years - pobj
# 				into - prep
# 						the - det
# 					future - pobj
# 					even - advmod
# 					when - advmod
# 						those - det
# 					decisions - nsubj
# 				are - advcl
# 					unpopular - acomp
# 						or - cc
# 						controversial - conj
# -------------------------------------------
# 	At - prep
# 			one - nummod
# 		point - pobj
# 	however - advmod
# 	he - nsubj
# wanted - ROOT
# 		a - det
# 		different - amod
# 	approach - dobj
# 		to - prep
# 			Trump - pobj
# -------------------------------------------
# 	Setting - advcl
# 			the - det
# 		stage - dobj
#
#  -
# 		Before - prep
# 				the - det
# 				2016 - nummod
# 			election - pobj
# 		the - det
# 	company - nsubj
# 	largely - advmod
# saw - ROOT
# 		its - poss
# 	role - dobj
# 		in - prep
# 			politics - pobj
# 	as - prep
# 		courting - pcomp
# 				political - amod
# 			leaders - dobj
# 				to - aux
# 			buy - xcomp
# 				ads - dobj
# 				and - cc
# 				broadcast - conj
# 						their - poss
# 					views - dobj
# 	according - prep
# 		to - prep
# 			people - pobj
# 				familiar - amod
# 					with - prep
# 							the - det
# 						company - pobj
# 	’s - punct
# 	thinking - advcl
# -------------------------------------------
# 	But - cc
# 	that - nsubj
# started - ROOT
# 		to - aux
# 	change - xcomp
# 		in - prep
# 			2015 - pobj
# 			as - mark
# 				Trump - poss
# 					’s - case
# 			candidacy - nsubj
# 		picked - advcl
# 			up - prt
# 			speed - dobj
# -------------------------------------------
# 	In - prep
# 		December - pobj
# 			of - prep
# 					that - det
# 				year - pobj
# 	he - nsubj
# posted - ROOT
# 		a - det
# 	video - dobj
# 			in - prep
# 				which - pobj
# 			he - nsubj
# 		said - relcl
# 				he - nsubj
# 			wanted - ccomp
# 					to - aux
# 				ban - xcomp
# 						all - det
# 					Muslims - dobj
# 					from - prep
# 						entering - pcomp
# 								the - det
# 								United - compound
# 							States - dobj
# -------------------------------------------
# 		The - det
# 	video - nsubj
# went - ROOT
# 	viral - acomp
# 	on - prep
# 		Facebook - pobj
# 	and - cc
# 	was - conj
# 			an - det
# 			early - amod
# 		indication - attr
# 			of - prep
# 					the - det
# 				tone - pobj
# 					of - prep
# 							his - poss
# 						candidacy - pobj
# -------------------------------------------
# 	Outrage - nsubj
# 		over - prep
# 				the - det
# 			video - pobj
# led - ROOT
# 	to - prep
# 			a - det
# 			companywide - compound
# 			town - compound
# 		hall - pobj
# 				in - prep
# 					which - pobj
# 				employees - nsubj
# 			decried - relcl
# 					the - det
# 				video - dobj
# 				as - prep
# 						hate - compound
# 					speech - pobj
# 	in - prep
# 		violation - pobj
# 			of - prep
# 						the - det
# 					company - poss
# 						’s - case
# 				policies - pobj
# -------------------------------------------
# 	And - cc
# 	in - prep
# 		meetings - pobj
# 			about - prep
# 					the - det
# 				issue - pobj
# 		senior - amod
# 	leaders - nsubj
# 		and - cc
# 			policy - compound
# 		experts - conj
# 	overwhelmingly - advmod
# said - ROOT
# 		they - nsubj
# 	felt - ccomp
# 			that - mark
# 				the - det
# 			video - nsubj
# 		was - ccomp
# 				hate - compound
# 			speech - attr
# 			according - prep
# 				to - prep
# 						three - nummod
# 						former - amod
# 					employees - pobj
# 							who - nsubj
# 						spoke - relcl
# 							on - prep
# 									the - det
# 								condition - pobj
# 									of - prep
# 										anonymity - pobj
# 							for - prep
# 								fear - pobj
# 									of - prep
# 										retribution - pobj
# -------------------------------------------
# 		Zuckerberg - nsubj
# 	expressed - ccomp
# 		in - prep
# 			meetings - pobj
# 			that - mark
# 			he - nsubjpass
# 			was - auxpass
# 			personally - advmod
# 		disgusted - ccomp
# 			by - agent
# 				it - pobj
# 			and - cc
# 			wanted - conj
# 					it - nsubj
# 				removed - ccomp
# 		the - det
# 	people - nsubj
# said - ROOT
# -------------------------------------------
# 	Some - nsubjpass
# 		of - prep
# 				these - det
# 			details - pobj
# 	were - auxpass
# 	previously - advmod
# reported - ROOT
# -------------------------------------------
# 	At - prep
# 		one - pobj
# 			of - prep
# 					the - det
# 				meetings - pobj
# 		Monika - compound
# 	Bickert - nsubj
# 			Facebook - nmod
# 				’s - case
# 			vice - compound
# 		president - appos
# 			for - prep
# 				policy - pobj
# drafted - ROOT
# 		a - det
# 	document - dobj
# 			to - aux
# 		address - relcl
# 				the - det
# 			video - dobj
# 			and - cc
# 			shared - conj
# 				it - dobj
# 				with - prep
# 					leaders - pobj
# 						including - prep
# 							Zuckerberg - pobj
# 								’s - punct
# 									top - amod
# 									deputy - compound
# 									COO - compound
# 									Sheryl - compound
# 								Sandberg - conj
# 									and - cc
# 										Vice - compound
# 									President - conj
# 										of - prep
# 													Global - compound
# 												Policy - compound
# 												Joel - compound
# 											Kaplan - pobj
# 								the - det
# 							company - pobj
# 								’s - punct
# 										most - advmod
# 									prominent - amod
# 								Republican - appos
# -------------------------------------------
# 		The - det
# 	document - nsubj
# 			which - nsubj
# 		is - relcl
# 				previously - advmod
# 			unreported - acomp
# 				and - cc
# 				obtained - conj
# 					by - agent
# 							The - det
# 						Post - pobj
# weighed - ROOT
# 		four - nummod
# 	options - dobj
# -------------------------------------------
# 	They - nsubj
# included - ROOT
# 	removing - xcomp
# 			the - det
# 		post - dobj
# 			for - prep
# 						hate - compound
# 					speech - compound
# 				violations - pobj
# 		making - advcl
# 				a - det
# 					one - nummod
# 				time - compound
# 			exception - dobj
# 				for - prep
# 					it - pobj
# 			creating - advcl
# 					a - det
# 					broad - amod
# 				exemption - dobj
# 					for - prep
# 							political - amod
# 						discourse - pobj
# 				and - cc
# 					even - advmod
# 				weakening - conj
# 							the - det
# 						company - poss
# 							’s - case
# 						community - compound
# 					guidelines - dobj
# 						for - prep
# 							everyone - pobj
# 					allowing - advcl
# 						comments - dobj
# 								such - amod
# 							as - prep
# 										No - det
# 									blacks - nsubj
# 								allowed - pcomp
# 									and - cc
# 									Get - conj
# 											the - det
# 										gays - dobj
# 										out - prep
# 											of - prep
# 													San - compound
# 												Francisco - pobj
# -------------------------------------------
# 			Facebook - compound
# 		spokesman - compound
# 		Tucker - compound
# 	Bounds - nsubj
# said - ROOT
# 			the - det
# 			latter - amod
# 		option - nsubjpass
# 		was - auxpass
# 		never - neg
# 		seriously - advmod
# 	considered - ccomp
# -------------------------------------------
# 		The - det
# 	document - nsubj
# 	also - advmod
# listed - ROOT
# 		possible - amod
# 		PR - compound
# 	Risks - dobj
# 	for - prep
# 		each - pobj
# -------------------------------------------
# 	For - prep
# 		example - pobj
# 	lowering - csubj
# 			the - det
# 		standards - dobj
# 		overall - advmod
# 	would - aux
# raise - ROOT
# 	questions - dobj
# 			such - amod
# 		as - prep
# 				Would - aux
# 				Facebook - nsubj
# 				have - aux
# 			provided - pcomp
# 					a - det
# 				platform - dobj
# 					for - prep
# 						Hitler - pobj
# -------------------------------------------
# 	Bickert - nsubj
# wrote - ROOT
# -------------------------------------------
# 		A - det
# 	carveout - nsubj
# 		for - prep
# 				political - amod
# 			speech - pobj
# 				across - prep
# 						the - det
# 					board - pobj
# 	on - prep
# 			the - det
# 			other - amod
# 		hand - pobj
# risked - ROOT
# 	opening - xcomp
# 			the - det
# 		floodgates - dobj
# 		for - prep
# 					even - advmod
# 				more - amod
# 				hateful - amod
# 				copycat - nmod
# 			comments - pobj
# -------------------------------------------
# 	Ultimately - advmod
# 	Zuckerberg - nsubjpass
# 	was - auxpass
# talked - ROOT
# 	out - prep
# 		of - prep
# 				his - poss
# 			desire - pobj
# 					to - aux
# 				remove - acl
# 						the - det
# 					post - dobj
# 					in - prep
# 						part - pobj
# 					by - prep
# 						Kaplan - pobj
# 	according - prep
# 		to - prep
# 				the - det
# 			people - pobj
# -------------------------------------------
# 	Instead - advmod
# 		the - det
# 	executives - nsubj
# created - ROOT
# 		an - det
# 	allowance - dobj
# 			that - mark
# 				newsworthy - amod
# 				political - amod
# 			discourse - nsubjpass
# 			would - aux
# 			be - auxpass
# 		taken - acl
# 			into - prep
# 				account - pobj
# 				when - advmod
# 			making - advcl
# 				decisions - dobj
# 					about - prep
# 							whether - mark
# 							posts - nsubj
# 						violated - pcomp
# 								community - compound
# 							guidelines - dobj
# -------------------------------------------
# 		That - det
# 	allowance - nsubjpass
# 	was - auxpass
# 	not - neg
# 	formally - advmod
# written - ROOT
# 	into - prep
# 			the - det
# 		policies - pobj
# 		even - advmod
# 		though - mark
# 		it - nsubj
# 	informed - advcl
# 			ad - compound
# 			hoc - amod
# 			decision - compound
# 		making - dobj
# 			about - prep
# 					political - amod
# 				speech - pobj
# 					for - prep
# 							the - det
# 							next - amod
# 							several - amod
# 						years - pobj
# 	according - prep
# 		to - prep
# 				the - det
# 			people - pobj
# -------------------------------------------
# 		When - advmod
# 			a - det
# 			formal - amod
# 			newsworthiness - amod
# 		policy - nsubjpass
# 		was - auxpass
# 	announced - advcl
# 		in - prep
# 			October - pobj
# 				2016 - nummod
# 	in - prep
# 			a - det
# 			blog - compound
# 		post - pobj
# 			by - prep
# 				Kaplan - pobj
# 		the - det
# 	company - nsubj
# 	did - aux
# 	not - neg
# discuss - ROOT
# 		Trump - poss
# 			’s - punct
# 	role - dobj
# 		in - prep
# 			shaping - pcomp
# 				it - dobj
# -------------------------------------------
# 	In - prep
# 			an - det
# 		interview - pobj
# 	Bickert - nsubj
# said - ROOT
# 			the - det
# 		company - nsubj
# 		ultimately - advmod
# 	made - ccomp
# 			a - det
# 		call - dobj
# 				to - aux
# 			maintain - relcl
# 					Trump - nmod
# 						’s - punct
# 					Muslim - amod
# 					ban - compound
# 				video - dobj
# 			because - mark
# 			executives - nsubj
# 		interpreted - advcl
# 			Trump - dobj
# 				’s - punct
# 				comment - conj
# 				to - aux
# 			mean - advcl
# 					that - mark
# 						the - det
# 						then - advmod
# 					candidate - nsubj
# 					was - aux
# 					not - neg
# 				speaking - ccomp
# 					about - prep
# 							all - det
# 						Muslims - pobj
# 			but - cc
# 				rather - advmod
# 			advocating - conj
# 				for - prep
# 						a - det
# 						policy - compound
# 					position - pobj
# 						on - prep
# 							immigration - pobj
# 				as - prep
# 					part - pobj
# 						of - prep
# 								a - det
# 								newsworthy - amod
# 								political - amod
# 							debate - pobj
# -------------------------------------------
# 	She - nsubj
# said - ROOT
# 		she - nsubj
# 		did - aux
# 		not - neg
# 	recall - ccomp
# 			the - det
# 		document - dobj
# 				where - advmod
# 					the - det
# 				options - nsubjpass
# 				were - auxpass
# 			presented - relcl
# -------------------------------------------
# 		Facebook - nmod
# 			’s - punct
# 	Bounds - nsubj
# added - ROOT
# 		that - mark
# 			the - det
# 			newsworthiness - amod
# 		policy - nsubjpass
# 		was - auxpass
# 	added - ccomp
# 		in - prep
# 			2016 - pobj
# 			after - mark
# 				content - compound
# 			reviewers - nsubj
# 		removed - advcl
# 				a - det
# 			photo - dobj
# 				of - prep
# 						a - det
# 						naked - amod
# 					girl - pobj
# 						fleeing - acl
# 								a - det
# 								napalm - compound
# 							attack - dobj
# 							during - prep
# 									the - det
# 									Vietnam - compound
# 								War - pobj
# -------------------------------------------
# 			Our - poss
# 		goal - nsubj
# 	was - ccomp
# 			to - aux
# 		recognize - xcomp
# 				the - det
# 				essential - amod
# 				public - amod
# 			benefit - dobj
# 				of - prep
# 						preserving - compound
# 					content - pobj
# 					that - mark
# 					in - prep
# 							other - amod
# 						contexts - pobj
# 					would - aux
# 					n’t - neg
# 					be - auxpass
# 				allowed - relcl
# 	Bounds - nsubj
# said - ROOT
# -------------------------------------------
# 	In - prep
# 			the - det
# 		case - pobj
# 			of - prep
# 					elected - amod
# 				officials - pobj
# 	it - nsubj
# 	also - advmod
# ensures - ROOT
# 		that - mark
# 		they - nsubjpass
# 		will - aux
# 		be - auxpass
# 	held - ccomp
# 			to - aux
# 		account - advcl
# 			for - prep
# 					their - poss
# 				words - pobj
# 		so - mark
# 		that - mark
# 		people - nsubj
# 		can - aux
# 	judge - advcl
# 		for - prep
# 			themselves - pobj
# -------------------------------------------
# 	In - prep
# 		spring - pobj
# 			of - prep
# 				2016 - pobj
# 	Zuckerberg - nsubjpass
# 	was - auxpass
# 	also - advmod
# talked - ROOT
# 	out - prep
# 		of - prep
# 				his - poss
# 			desire - pobj
# 					to - aux
# 				write - acl
# 						a - det
# 					post - dobj
# 							specifically - advmod
# 						condemning - acl
# 							Trump - dobj
# 							for - prep
# 									his - poss
# 								calls - pobj
# 										to - aux
# 									build - acl
# 											a - det
# 										wall - dobj
# 											between - prep
# 													the - det
# 													United - compound
# 												States - pobj
# 													and - cc
# 													Mexico - conj
# 		after - mark
# 		advisers - nsubj
# 			in - prep
# 				Washington - pobj
# 	warned - advcl
# 			it - nsubj
# 			could - aux
# 		look - ccomp
# 			like - prep
# 				choosing - pcomp
# 					sides - dobj
# 		according - prep
# 			to - prep
# 					Dex - compound
# 					Torricke - compound
# 				Barton - pobj
# 					one - appos
# 						of - prep
# 							Zuckerberg - pobj
# 					’s - punct
# 						former - amod
# 					speechwriters - appos
# -------------------------------------------
# 		The - det
# 			political - amod
# 		speech - compound
# 	carveout - nsubj
# ended - ROOT
# 	up - prt
# 	setting - xcomp
# 			the - det
# 		stage - dobj
# 		for - prep
# 				how - advmod
# 					the - det
# 				company - nsubj
# 				would - aux
# 			handle - pcomp
# 					not - preconj
# 						only - advmod
# 				Trump - dobj
# 					but - cc
# 						populist - amod
# 					leaders - conj
# 						around - prep
# 								the - det
# 							world - pobj
# 							who - nsubj
# 							have - aux
# 						posted - relcl
# 							content - dobj
# 								that - nsubj
# 							test - ccomp
# 									these - det
# 								boundaries - dobj
# 									such - amod
# 								as - prep
# 										Rodrigo - compound
# 									Duterte - pobj
# 										in - prep
# 												the - det
# 											Philippines - pobj
# 											Jair - compound
# 										Bolsonaro - conj
# 											in - prep
# 												Brazil - pobj
# 											and - cc
# 												Narendra - compound
# 											Modi - conj
# 												in - prep
# 													India - pobj
# -------------------------------------------
# 			Though - mark
# 			Facebook - nsubj
# 			has - aux
# 		cracked - advcl
# 			down - prt
# 			on - prep
# 				misinformation - pobj
# 			the - det
# 				most - advmod
# 			problematic - amod
# 		influencers - nsubj
# 	are - ccomp
# 		politicians - attr
# said - ROOT
# 		Claire - compound
# 	Wardle - nsubj
# 			U.S. - compound
# 		director - appos
# 			of - prep
# 					First - compound
# 				Draft - pobj
# 						an - det
# 					organization - appos
# 						dedicated - acl
# 							to - prep
# 								fighting - pcomp
# 									misinformation - dobj
# 											that - nsubj
# 										has - relcl
# 												a - det
# 											partnership - dobj
# 												with - prep
# 													Facebook - pobj
# -------------------------------------------
# 	You - nsubj
# 	can - aux
# do - ROOT
# 		all - predet
# 		the - det
# 	fact - dobj
# 		checking - acl
# 			in - prep
# 					the - det
# 				world - pobj
# 	but - cc
# 			these - det
# 		influencers - nsubj
# 	have - conj
# 			a - det
# 			disproportionate - amod
# 		impact - dobj
# -------------------------------------------
# 		Trump - nsubj
# 	presented - ccomp
# 			a - det
# 			unique - amod
# 		challenge - dobj
# 	she - nsubj
# added - ROOT
# -------------------------------------------
# 	Until - prep
# 		then - pcomp
# 		no - det
# 	one - nsubj
# 	would - aux
# 	have - aux
# considered - ROOT
# 		a - det
# 	president - dobj
# 			who - nsubj
# 			would - aux
# 			have - aux
# 		said - relcl
# 				those - det
# 			things - dobj
# -------------------------------------------
# Protecting - ROOT
# 		the - det
# 	right - dobj
#
#  -
# -------------------------------------------
# 	After - prep
# 			the - det
# 		election - pobj
# 	it - nsubj
# became - ROOT
# 	clear - acomp
# 		Russia - nsubj
# 		had - aux
# 	used - ccomp
# 			social - amod
# 		media - dobj
# 			to - aux
# 		sow - xcomp
# 			disinformation - dobj
# -------------------------------------------
# 	Facebook - nsubj
# 	soon - advmod
# 	after - mark
# became - ROOT
# 		a - det
# 		frequent - amod
# 	target - attr
# 		of - prep
# 				the - det
# 			president - pobj
# 				’s - punct
# 				ire - appos
# -------------------------------------------
# 	He - nsubj
# tweeted - ROOT
# 		that - mark
# 			the - det
# 				social - amod
# 			media - compound
# 		giant - nsubj
# 	was - ccomp
# 		Trump - acomp
# 		and - cc
# 	trying - advcl
# 			to - aux
# 		undermine - xcomp
# 				his - poss
# 			victory - dobj
# -------------------------------------------
# 	At - prep
# 			the - det
# 			same - amod
# 		time - pobj
# 		GOP - compound
# 	leaders - nsubj
# stepped - ROOT
# 	up - prt
# 	criticism - dobj
# 			that - nsubj
# 		platforms - relcl
# 				such - amod
# 			as - prep
# 				Facebook - pobj
# 					and - cc
# 					Twitter - conj
# 		with - mark
# 		leadership - nsubj
# 	ranks - advcl
# 		full - acomp
# 			of - prep
# 				liberals - pobj
# 		sought - conj
# 				to - aux
# 			limit - xcomp
# 					the - det
# 				reach - dobj
# 					of - prep
# 								right - advmod
# 							leaning - amod
# 						voices - pobj
# -------------------------------------------
# 		There - advmod
# 		’s - punct
# 			no - det
# 			credible - amod
# 		research - nsubj
# 			supporting - acl
# 				Trump - dobj
# 			’s - punct
# 	claim - ccomp
# 			that - mark
# 				social - amod
# 			platforms - nsubj
# 		suppress - ccomp
# 				conservative - amod
# 			content - dobj
# 		but - cc
# 			he - nsubj
# 			still - advmod
# 		succeeded - conj
# 			in - prep
# 				getting - pcomp
# 						them - nsubj
# 						to - aux
# 					revise - ccomp
# 							their - poss
# 						rules - dobj
# 						for - prep
# 							him - pobj
# said - ROOT
# 			former - amod
# 			Facebook - compound
# 		spokesman - compound
# 		Nu - compound
# 	Wexler - nsubj
# 			who - nsubj
# 		left - relcl
# 				the - det
# 			company - dobj
# 			in - prep
# 				2018 - pobj
# -------------------------------------------
# 		As - mark
# 		Facebook - nsubj
# 	scrambled - advcl
# 			to - aux
# 		tackle - xcomp
# 				foreign - amod
# 			interference - dobj
# 				and - cc
# 				misinformation - conj
# 		its - poss
# 	executives - nsubj
# 		in - prep
# 				the - det
# 			nation - pobj
# 		’s - punct
# 		capital - appos
# argued - ROOT
# 		that - mark
# 		caution - nsubj
# 			and - cc
# 			deference - conj
# 	was - ccomp
# 		necessary - acomp
# 				to - aux
# 			survive - xcomp
# 					the - det
# 					new - amod
# 					political - amod
# 				environment - dobj
# 	according - prep
# 		to - prep
# 				three - nummod
# 			people - pobj
# 				familiar - amod
# 					with - prep
# 							the - det
# 						company - pobj
# 				’s - punct
# 		thinking - pobj
# -------------------------------------------
# 		Facebook - nmod
# 			’s - punct
# 		security - compound
# 	engineers - nsubj
# 		in - prep
# 			December - pobj
# 				2016 - nummod
# presented - ROOT
# 	findings - dobj
# 	from - prep
# 			a - det
# 			broad - amod
# 			internal - amod
# 		investigation - pobj
# 			known - acl
# 				as - prep
# 						Project - compound
# 					P - pobj
# 	to - prep
# 			senior - amod
# 		leadership - pobj
# 			on - prep
# 							how - advmod
# 						false - amod
# 							and - cc
# 							misleading - conj
# 						news - compound
# 					reports - nsubj
# 				spread - pcomp
# 						so - advmod
# 					virally - advmod
# 					during - prep
# 							the - det
# 						election - pobj
# -------------------------------------------
# 		When - advmod
# 			Facebook - nmod
# 				’s - punct
# 			security - compound
# 		team - nsubj
# 	highlighted - advcl
# 		dozens - dobj
# 			of - prep
# 				pages - pobj
# 						that - nsubj
# 						had - aux
# 					peddled - relcl
# 							false - amod
# 							news - compound
# 						reports - dobj
# 				senior - amod
# 			leaders - appos
# 				in - prep
# 					Washington - pobj
# 				including - prep
# 					Kaplan - pobj
# opposed - ROOT
# 	shutting - xcomp
# 		them - dobj
# 		down - prt
# 		immediately - advmod
# 	arguing - advcl
# 			that - mark
# 			doing - csubj
# 				so - advmod
# 			would - aux
# 			disproportionately - advmod
# 		impact - ccomp
# 			conservatives - dobj
# 		according - prep
# 			to - prep
# 				people - pobj
# 					familiar - amod
# 						with - prep
# 								the - det
# 							company - pobj
# 			’s - punct
# 			thinking - pobj
# -------------------------------------------
# 	Ultimately - advmod
# 		the - det
# 	company - nsubj
# shut - ROOT
# 	down - prt
# 			far - advmod
# 		fewer - amod
# 	pages - dobj
# 			than - mark
# 			were - auxpass
# 			originally - advmod
# 		proposed - advcl
# 				while - mark
# 				it - nsubj
# 			began - advcl
# 				developing - xcomp
# 						a - det
# 					policy - dobj
# 							to - aux
# 						handle - relcl
# 								these - det
# 							issues - dobj
# -------------------------------------------
# 				A - det
# 			year - npadvmod
# 		later - advmod
# 		Facebook - nsubj
# 	considered - ccomp
# 			how - advmod
# 			to - aux
# 		overhaul - xcomp
# 				its - poss
# 				scrolling - compound
# 				news - compound
# 			feed - dobj
# 		the - det
# 		homepage - compound
# 	screen - nsubj
# 		most - amod
# 	users - nsubj
# see - ROOT
# 		when - advmod
# 		they - nsubj
# 	open - advcl
# 			the - det
# 		site - dobj
# -------------------------------------------
# 	As - prep
# 		part - pobj
# 			of - prep
# 					the - det
# 				change - pobj
# 			to - aux
# 		help - pcomp
# 			limit - xcomp
# 				misinformation - dobj
# 	it - nsubj
# changed - ROOT
# 		its - poss
# 			news - compound
# 		feed - compound
# 	algorithm - dobj
# 		to - aux
# 	focus - advcl
# 		more - advmod
# 		on - prep
# 			posts - pobj
# 				by - prep
# 					friends - pobj
# 						and - cc
# 						family - conj
# 				versus - prep
# 					publishers - pobj
# -------------------------------------------
# 	In - prep
# 		meetings - pobj
# 			about - prep
# 					the - det
# 				change - pobj
# 	Kaplan - nsubj
# questioned - ROOT
# 		whether - mark
# 			the - det
# 			revamped - amod
# 		algorithm - nsubj
# 		would - aux
# 	hurt - ccomp
# 				right - advmod
# 			leaning - amod
# 		publishers - dobj
# 		more - advmod
# 			than - prep
# 				others - pobj
# 		according - prep
# 			to - prep
# 					three - nummod
# 				people - pobj
# 					familiar - amod
# 						with - prep
# 								the - det
# 							company - pobj
# 					’s - punct
# 			thinking - pobj
# 					who - nsubj
# 				spoke - relcl
# 					on - prep
# 							the - det
# 						condition - pobj
# 							of - prep
# 								anonymity - pobj
# 					for - prep
# 						fear - pobj
# 							of - prep
# 								retribution - pobj
# -------------------------------------------
# 				When - advmod
# 					the - det
# 				data - nsubj
# 			showed - advcl
# 					it - nsubj
# 				would - ccomp
# 				conservative - amod
# 				leaning - amod
# 			outlets - nsubj
# 			were - aux
# 		pushing - ccomp
# 				more - amod
# 			content - dobj
# 					that - nsubj
# 				violated - relcl
# 						its - poss
# 					policies - dobj
# 					the - det
# 				company - nsubj
# 				had - aux
# 			found - conj
# 		he - nsubj
# 		successfully - advmod
# 	pushed - ccomp
# 		for - prep
# 			changes - pobj
# 			to - aux
# 		make - advcl
# 					the - det
# 					new - amod
# 				algorithm - nsubj
# 				to - aux
# 			be - ccomp
# 					what - dobj
# 					he - nsubj
# 				considered - ccomp
# 						more - advmod
# 					evenhanded - oprd
# 						in - prep
# 								its - poss
# 							impact - pobj
# 		the - det
# 	people - nsubj
# said - ROOT
# -------------------------------------------
# Isolated - ROOT
# 	and - cc
# 	divided - conj
#
#  -
# 		With - prep
# 				the - det
# 				2020 - nummod
# 			election - pobj
# 				on - prep
# 						the - det
# 					horizon - pobj
# 						Facebook - conj
# 							and - cc
# 							Zuckerberg - conj
# 	’s - punct
# -------------------------------------------
# 		hands - nmod
# 			off - prt
# 	approach - nsubj
# 		to - prep
# 				free - amod
# 			speech - pobj
# 	was - aux
# leaving - ROOT
# 	it - dobj
# 		increasingly - advmod
# 	isolated - oprd
# 		in - prep
# 				Silicon - compound
# 			Valley - pobj
# -------------------------------------------
# 	In - prep
# 		May - pobj
# 			2019 - nummod
# 	Zuckerberg - nsubj
# 	citing - advcl
# 			free - amod
# 		speech - dobj
# refused - ROOT
# 		to - aux
# 	take - xcomp
# 		down - prt
# 			a - det
# 			doctored - amod
# 		video - dobj
# 			of - prep
# 						House - compound
# 					Speaker - compound
# 					Nancy - compound
# 				Pelosi - pobj
# 						D - compound
# 					Calif - appos
# -------------------------------------------
# 	that - nsubj
# made - ROOT
# 		her - nsubj
# 	appear - ccomp
# 		drunk - oprd
# -------------------------------------------
# 		That - det
# 	summer - npadvmod
# 		company - compound
# 	leaders - nsubj
# held - ROOT
# 		a - det
# 	meeting - dobj
# 		to - aux
# 	revisit - advcl
# 			its - poss
# 			newsworthiness - amod
# 		exception - dobj
# 				which - nsubjpass
# 				until - prep
# 					then - pcomp
# 				had - aux
# 				been - auxpass
# 			determined - relcl
# 				on - prep
# 						a - det
# 						case - nmod
# 							by - prep
# 								case - pobj
# 					basis - pobj
# 				with - prep
# 						the - det
# 							most - advmod
# 						controversial - amod
# 					calls - pobj
# 						made - acl
# 							by - agent
# 								Zuckerberg - pobj
# -------------------------------------------
# 	Internally - advmod
# 	some - nsubj
# were - ROOT
# 	unclear - acomp
# 			how - advmod
# 		far - advmod
# 			that - det
# 		leeway - nsubj
# 	extended - advcl
# 	according - prep
# 		to - prep
# 				two - nummod
# 			people - pobj
# -------------------------------------------
# 	Clegg - nsubj
# 			the - det
# 		company - appos
# 			’s - punct
# 				new - amod
# 			head - appos
# 				of - prep
# 						global - amod
# 					affairs - pobj
# 						and - cc
# 						communications - conj
# 				and - cc
# 					a - det
# 					former - amod
# 					British - amod
# 					deputy - amod
# 					prime - compound
# 				minister - conj
# announced - ROOT
# 		the - det
# 	outcome - dobj
# 		of - prep
# 				that - det
# 			meeting - pobj
# 		at - prep
# 				a - det
# 			speech - pobj
# 				in - prep
# 					Washington - pobj
# 		in - prep
# 			September - pobj
# 				2019 - nummod
# -------------------------------------------
# 	Aside - advmod
# 		from - prep
# 			speech - pobj
# 					that - nsubj
# 				causes - relcl
# 					violence - dobj
# 						or - cc
# 								real - amod
# 							world - compound
# 						harm - conj
# 	Facebook - nsubj
# 	would - aux
# allow - ROOT
# 		politicians - nsubj
# 		to - aux
# 	express - ccomp
# 		themselves - dobj
# 			virtually - advmod
# 		unchecked - oprd
# 			on - prep
# 					social - amod
# 				media - pobj
# -------------------------------------------
# 		Facebook - nmod
# 			’s - punct
# 	network - nsubj
# 		of - prep
# 				independent - amod
# 				fact - compound
# 			checkers - pobj
# 					which - nsubjpass
# 					had - aux
# 					been - auxpass
# 				established - relcl
# 					as - prep
# 							a - det
# 							key - amod
# 						part - pobj
# 							of - prep
# 									the - det
# 								company - pobj
# 		’s - punct
# 		response - appos
# 			to - prep
# 				disinformation - pobj
# 	would - aux
# 	not - neg
# evaluate - ROOT
# 		their - poss
# 	claims - dobj
# 		and - cc
# 			the - det
# 			community - compound
# 		guidelines - conj
# 		would - aux
# 		largely - advmod
# 		not - neg
# 	apply - conj
# 		to - prep
# 			politicians - pobj
# -------------------------------------------
# 		Facebook - nsubj
# 		did - aux
# 		not - neg
# 	want - ccomp
# 			to - aux
# 		be - xcomp
# 				an - det
# 			arbiter - attr
# 				of - prep
# 					truth - pobj
# 				in - prep
# 						political - amod
# 					debate - pobj
# 	he - nsubj
# said - ROOT
# 	echoing - advcl
# 			Zuckerberg - poss
# 				’s - punct
# 				long - advmod
# 			standing - amod
# 		position - dobj
# -------------------------------------------
# 		The - det
# 	speech - nsubj
# angered - ROOT
# 		some - det
# 	employees - dobj
# 	triggering - advcl
# 			more - amod
# 			than - quantmod
# 		250 - dobj
# 			of - prep
# 				them - pobj
# 			to - aux
# 		sign - xcomp
# 				a - det
# 			petition - dobj
# 				disagreeing - acl
# 					with - prep
# 							the - det
# 						decision - pobj
# 				because - mark
# 				they - nsubj
# 			thought - advcl
# 					it - nsubj
# 				gave - ccomp
# 					politicians - dative
# 						a - det
# 					pass - dobj
# -------------------------------------------
# 		One - nummod
# 		former - amod
# 	executive - nsubj
# 			Yael - compound
# 		Eisenstat - appos
# 			who - nsubj
# 		worked - relcl
# 				to - aux
# 			improve - advcl
# 					the - det
# 						political - amod
# 					ads - compound
# 				process - dobj
# wrote - ROOT
# 	in - prep
# 			The - det
# 		Post - pobj
# 		that - mark
# 			the - det
# 		controversy - nsubj
# 	was - ccomp
# 			the - det
# 			biggest - amod
# 		test - attr
# 			of - prep
# 					whether - mark
# 					Facebook - nsubj
# 					will - aux
# 					ever - advmod
# 					truly - advmod
# 				put - pcomp
# 					society - dobj
# 						and - cc
# 						democracy - conj
# 					ahead - advmod
# 						of - prep
# 							profit - pobj
# 								and - cc
# 								ideology - conj
# -------------------------------------------
# 	She - nsubj
# said - ROOT
# 		that - mark
# 		she - nsubj
# 		routinely - advmod
# 	experienced - ccomp
# 			how - advmod
# 					the - det
# 				company - poss
# 					’s - case
# 			efforts - nsubjpass
# 				at - prep
# 					integrity - pobj
# 			were - auxpass
# 			often - advmod
# 		undermined - ccomp
# 			by - agent
# 					the - det
# 					few - amod
# 				voices - pobj
# 						who - nsubj
# 						ultimately - advmod
# 					decided - relcl
# 							the - det
# 						company - dobj
# 					’s - punct
# 						overall - amod
# 					direction - appos
# -------------------------------------------
# 	Meanwhile - advmod
# 	in - prep
# 		October - pobj
# 		as - mark
# 		Facebook - nsubj
# 	faced - advcl
# 			more - amod
# 			potential - amod
# 		regulation - dobj
# 			and - cc
# 				political - amod
# 			troubles - conj
# 	Zuckerberg - nsubj
# 		and - cc
# 			his - poss
# 		wife - conj
# 				Priscilla - compound
# 			Chan - appos
# went - ROOT
# 	to - prep
# 			the - det
# 			White - compound
# 		House - pobj
# 	for - prep
# 			a - det
# 			private - amod
# 		dinner - pobj
# 			with - prep
# 				Trump - pobj
# 						a - det
# 					part - appos
# 						of - prep
# 								the - det
# 							CEO - pobj
# 	’s - punct
# -------------------------------------------
# effort - ROOT
# 		to - aux
# 	cultivate - acl
# 			personal - amod
# 		relationships - dobj
# 			in - prep
# 				Washington - pobj
# -------------------------------------------
# Tweetstorm - ROOT
#
#  -
# -------------------------------------------
# 		As - mark
# 			the - det
# 		pandemic - nsubj
# 			and - cc
# 				civil - amod
# 			unrest - conj
# 	dominated - advcl
# 			the - det
# 			first - amod
# 		half - dobj
# 			of - prep
# 					this - det
# 				year - pobj
# 	Trump - nsubj
# continued - ROOT
# 		to - aux
# 	turn - xcomp
# 		to - prep
# 				social - amod
# 				media - compound
# 			platforms - pobj
# 			to - aux
# 		spread - xcomp
# 			misinformation - dobj
# -------------------------------------------
# 	He - nsubj
# touted - ROOT
# 		the - det
# 		unproven - amod
# 		drug - compound
# 	hydroxychloroquine - dobj
# 	as - prep
# 			a - det
# 			possible - amod
# 		cure - pobj
# 			for - prep
# 					the - det
# 				coronavirus - pobj
# 	and - cc
# 	claimed - conj
# 		without - prep
# 			evidence - pobj
# 					that - mark
# 						the - det
# 							left - amod
# 						wing - amod
# 						antifa - compound
# 					movement - nsubj
# 				was - acl
# 					behind - prep
# 							the - det
# 						violence - pobj
# 							at - prep
# 										George - compound
# 									Floyd - compound
# 								protests - pobj
# -------------------------------------------
# 	Meanwhile - advmod
# 		Facebook - compound
# 	employees - nsubj
# began - ROOT
# 	challenging - xcomp
# 				the - det
# 			company - poss
# 				’s - punct
# 		decisions - dobj
# -------------------------------------------
# 			Two - nummod
# 		months - npadvmod
# 	before - prep
# 		Trump - pobj
# 			’s - punct
# 			looting - appos
# 				shooting - conj
# 					post - dobj
# 		the - det
# 		Brazilian - amod
# 	president - nsubj
# posted - ROOT
# 	about - prep
# 				the - det
# 			country - poss
# 				’s - case
# 			indigenous - amod
# 		population - pobj
# 	saying - advcl
# 			Indians - nsubj
# 			are - aux
# 			undoubtedly - advmod
# 		changing - ccomp
# -------------------------------------------
# 	They - nsubj
# 	are - aux
# 	increasingly - advmod
# becoming - ROOT
# 		human - amod
# 	beings - attr
# 		just - advmod
# 	like - prep
# 		us - pobj
# -------------------------------------------
# 	Thiel - nsubj
# 			the - det
# 			security - compound
# 		engineer - appos
# 			and - cc
# 				other - amod
# 			employees - conj
# argued - ROOT
# 	internally - advmod
# 		that - mark
# 		it - nsubj
# 	violated - ccomp
# 			the - det
# 		company - dobj
# 		’s - punct
# 			internal - amod
# 		guidelines - dobj
# 			against - prep
# 					dehumanizing - amod
# 				speech - pobj
# -------------------------------------------
# 	They - nsubj
# 	were - aux
# referring - ROOT
# 	to - prep
# 		Zuckerberg - pobj
# 	’s - punct
# 		own - amod
# 	words - dobj
# 			in - prep
# 				which - pobj
# 			he - nsubj
# 		said - relcl
# 					dehumanizing - amod
# 				speech - nsubj
# 			is - ccomp
# 					the - det
# 					first - amod
# 				step - attr
# 					toward - prep
# 						inciting - pcomp
# 							violence - dobj
# 		while - mark
# 	testifying - advcl
# 		before - prep
# 			Congress - pobj
# 		in - prep
# 			October - pobj
# -------------------------------------------
# 	In - prep
# 			internal - amod
# 		correspondence - pobj
# 	Thiel - nsubjpass
# 	was - auxpass
# told - ROOT
# 		that - mark
# 		it - nsubj
# 		did - aux
# 		n’t - neg
# 	qualify - ccomp
# 		as - prep
# 			racism - pobj
# 		and - cc
# 			may - aux
# 			have - aux
# 			even - advmod
# 		been - conj
# 				a - det
# 				positive - amod
# 			reference - attr
# 				to - prep
# 					integration - pobj
# -------------------------------------------
# 	Thiel - nsubj
# quit - ROOT
# 	in - prep
# 		disgust - pobj
# -------------------------------------------
# 	In - prep
# 		May - pobj
# 	following - prep
# 		years - pobj
# 			of - prep
# 					internal - amod
# 				debate - pobj
# 					of - prep
# 							its - poss
# 						own - pobj
# 	Twitter - nsubj
# chose - ROOT
# 		to - aux
# 	go - xcomp
# 		in - prep
# 				the - det
# 				opposite - amod
# 			direction - pobj
# -------------------------------------------
# 	It - nsubj
# labeled - ROOT
# 		two - nummod
# 		misleading - amod
# 	tweets - dobj
# 	by - prep
# 		Trump - pobj
# 			about - prep
# 				mail - pobj
# 	in - prep
# 		ballots - pobj
# 			with - prep
# 					a - det
# 						fact - compound
# 					check - compound
# 				label - pobj
# -------------------------------------------
# 	Trump - nsubj
# responded - ROOT
# 			two - nummod
# 		days - npadvmod
# 	later - advmod
# 	with - prep
# 			an - det
# 			executive - amod
# 		order - pobj
# 				that - nsubj
# 				could - aux
# 			hurt - relcl
# 					social - amod
# 					media - compound
# 				companies - dobj
# 				by - prep
# 					removing - pcomp
# 							a - det
# 							key - amod
# 						exception - dobj
# 								that - nsubj
# 							limits - relcl
# 									their - poss
# 								liability - dobj
# 									for - prep
# 										content - pobj
# 											posted - acl
# 												on - prep
# 														their - poss
# 													sites - pobj
# -------------------------------------------
# 		President - compound
# 	Trump - nsubj
# 		with - prep
# 					Attorney - compound
# 				General - compound
# 				William - compound
# 				P. - compound
# 			Barr - pobj
# speaks - ROOT
# 	in - prep
# 			the - det
# 			Oval - compound
# 		Office - pobj
# 	before - prep
# 		signing - pcomp
# 				an - det
# 				executive - amod
# 			order - dobj
# 				related - acl
# 					to - prep
# 						regulating - pcomp
# 								social - amod
# 							media - dobj
# 							on - prep
# 								May - pobj
# 									28 - nummod
# -------------------------------------------
# 	Pool - nmod
# Photographer - ROOT
# 		/Getty - punct
# 	Images - appos
# -------------------------------------------
# 		The - det
# 		next - amod
# 	day - npadvmod
# 	Trump - nsubj
# tweeted - ROOT
# 	about - prep
# 			the - det
# 			Minnesota - compound
# 		protests - pobj
# -------------------------------------------
# 	Twitter - nsubj
# 	quickly - advmod
# labeled - ROOT
# 		the - det
# 	tweet - dobj
# 	for - prep
# 		violating - pcomp
# 			rules - dobj
# 				about - prep
# 					glorifying - pcomp
# 						violence - dobj
# 	and - cc
# 		Snapchat - nsubj
# 	stopped - conj
# 		promoting - xcomp
# 			Trump - dobj
# 		’s - punct
# 		account - xcomp
# 				the - det
# 				following - amod
# 			week - npadvmod
# -------------------------------------------
# 	YouTube - nsubj
# told - ROOT
# 		The - det
# 	Post - dobj
# 		that - mark
# 		it - nsubj
# 	holds - ccomp
# 		politicians - dobj
# 		to - prep
# 				the - det
# 				same - amod
# 			standards - pobj
# 				as - prep
# 					everyone - pobj
# 						else - advmod
# -------------------------------------------
# 		Facebook - nsubj
# 		on - prep
# 				the - det
# 				other - amod
# 			hand - pobj
# 	chose - ccomp
# 			to - aux
# 		haggle - xcomp
# 			with - prep
# 					the - det
# 					White - compound
# 				House - pobj
# 		asking - advcl
# 			for - prep
# 					a - det
# 				deletion - pobj
# 					or - cc
# 						a - det
# 					change - conj
# said - ROOT
# 		the - det
# 	people - nsubj
# -------------------------------------------
# 	Axios - nsubj
# 	first - advmod
# reported - ROOT
# 		the - det
# 	call - dobj
# 			which - dobj
# 				Facebook - nmod
# 					’s - punct
# 			Bounds - nsubj
# 		confirmed - relcl
# 			to - prep
# 					The - det
# 				Post - pobj
# -------------------------------------------
# 		As - mark
# 		employees - nsubj
# 	raged - advcl
# 		on - prep
# 				internal - amod
# 				message - compound
# 			boards - pobj
# 		and - cc
# 			externally - advmod
# 		on - conj
# 			Twitter - pobj
# 	Zuckerberg - nsubj
# told - ROOT
# 	workers - dobj
# 		that - mark
# 			Facebook - nmod
# 				’s - punct
# 		policies - nsubj
# 		might - aux
# 	change - ccomp
# 		again - advmod
# 		in - prep
# 			light - pobj
# 				of - prep
# 						Trump - poss
# 							’s - case
# 					post - pobj
# -------------------------------------------
# 			The - det
# 		company - nsubj
# 	had - ccomp
# 		rules - dobj
# 			allowing - acl
# 				for - prep
# 						state - compound
# 					use - pobj
# 						of - prep
# 							force - pobj
# 	he - nsubj
# said - ROOT
# 	but - cc
# 		they - nsubj
# 	were - conj
# 		vague - acomp
# 		and - cc
# 			did - aux
# 			n’t - neg
# 		encompass - conj
# 				the - det
# 			possibility - dobj
# 					that - mark
# 						such - amod
# 					pronouncements - nsubj
# 					could - aux
# 				signal - acl
# 						harmful - amod
# 					aggression - dobj
# -------------------------------------------
# 		Bickert - nmod
# 			’s - punct
# 	team - nsubj
# planned - ROOT
# 		a - det
# 	series - dobj
# 		of - prep
# 				policy - compound
# 			meetings - pobj
# 		for - prep
# 				the - det
# 			weeks - pobj
# 				ahead - advmod
# -------------------------------------------
# 	In - prep
# 		June - pobj
# 	Facebook - nsubj
# removed - ROOT
# 		a - det
# 	swath - dobj
# 		of - prep
# 				Trump - compound
# 				campaign - compound
# 			ads - pobj
# 				with - prep
# 						Nazi - compound
# 					symbolism - pobj
# 	after - prep
# 			an - det
# 			initial - amod
# 			internal - amod
# 		assessment - pobj
# 				that - nsubj
# 			found - relcl
# 						the - det
# 					ads - nsubj
# 					did - aux
# 					not - neg
# 				violate - ccomp
# 							the - det
# 						company - poss
# 							’s - punct
# 					polices - dobj
# 	according - prep
# 		to - prep
# 			documents - pobj
# 				viewed - acl
# 					by - agent
# 							The - det
# 						Post - pobj
# -------------------------------------------
# 	In - prep
# 		meetings - pobj
# 		senior - amod
# 	executives - nsubj
# argued - ROOT
# 		that - mark
# 			not - neg
# 		removing - csubjpass
# 			them - dobj
# 		would - aux
# 		be - auxpass
# 	perceived - ccomp
# 		as - prep
# 			pandering - pcomp
# 					too - advmod
# 				much - dobj
# 				to - prep
# 						the - det
# 					president - pobj
# 		according - prep
# 			to - prep
# 					a - det
# 				person - pobj
# 					familiar - amod
# 						with - prep
# 								the - det
# 							discussions - pobj
# -------------------------------------------
# 		Last - amod
# 	week - npadvmod
# 		the - det
# 		advertiser - compound
# 	boycott - nsubj
# picked - ROOT
# 	up - prt
# 	steam - dobj
# -------------------------------------------
# 	Hershey - nsubj
# 		Verizon - conj
# 			Unilever - conj
# 					Coca - compound
# 				Cola - conj
# 					and - cc
# 					others - conj
# said - ROOT
# 		they - nsubj
# 		were - aux
# 		temporarily - advmod
# 	pulling - ccomp
# 		ads - dobj
# -------------------------------------------
# 	On - prep
# 		Friday - pobj
# 	Zuckerberg - nsubj
# told - ROOT
# 	employees - dobj
# 	in - prep
# 			a - det
# 				live - advmod
# 			streamed - amod
# 			town - compound
# 		hall - pobj
# 				that - mark
# 				he - nsubj
# 				was - aux
# 			changing - relcl
# 					the - det
# 				company - dobj
# 				’s - prep
# 				policy - dobj
# 					to - aux
# 				label - advcl
# 						problematic - amod
# 						newsworthy - amod
# 					content - dobj
# 							that - nsubj
# 						violated - relcl
# 									the - det
# 								company - poss
# 									’s - case
# 							policies - dobj
# 								as - mark
# 								Twitter - nsubj
# 							does - advcl
# 							a - det
# 							major - amod
# 						concession - appos
# 							amid - prep
# 									the - det
# 									rising - amod
# 								tide - pobj
# 									of - prep
# 										criticism - pobj
# -------------------------------------------
# 	He - nsubj
# 	also - advmod
# said - ROOT
# 	in - prep
# 			the - det
# 				most - advmod
# 			explicit - amod
# 		language - pobj
# 			ever - advmod
# 		that - mark
# 			the - det
# 		company - nsubj
# 		would - aux
# 	remove - ccomp
# 		posts - dobj
# 			by - prep
# 				politicians - pobj
# 						that - nsubj
# 					incite - relcl
# 						violence - dobj
# 						and - cc
# 							suppress - amod
# 						voting - conj
# -------------------------------------------
# 	Still - advmod
# 			civil - amod
# 		rights - compound
# 	leaders - nsubj
# said - ROOT
# 			his - poss
# 		assertions - nsubj
# 		did - aux
# 		n’t - neg
# 	go - ccomp
# 			far - advmod
# 		enough - advmod
# -------------------------------------------
# 		There - expl
# 	are - ccomp
# 			no - det
# 		exceptions - attr
# 			for - prep
# 				politicians - pobj
# 					in - prep
# 						any - pobj
# 							of - prep
# 									the - det
# 								policies - pobj
# 										that - dobj
# 										I - nsubj
# 										’m - aux
# 									announcing - relcl
# 										today - npadvmod
# 	Zuckerberg - nsubj
# said - ROOT
# -------------------------------------------

# %% [markdown]
# ### 4. Show the most common Entities and their types.

# %%
counts = Counter()
for entity in processed_text.ents:
    counts[entity.text.upper(), entity.label_] += 1
counts.most_common(15)
# Out:
# [(('FACEBOOK', 'ORG'), 39),
#  (('ZUCKERBERG', 'PERSON'), 21),
#  (('TRUMP', 'PERSON'), 13),
#  (('TRUMP', 'ORG'), 13),
#  (('WASHINGTON', 'GPE'), 5),
#  (('ONE', 'CARDINAL'), 5),
#  (('THE UNITED STATES', 'GPE'), 4),
#  (('SILICON VALLEY', 'LOC'), 4),
#  (('FACEBOOK', 'GPE'), 4),
#  (('THE WHITE HOUSE', 'ORG'), 3),
#  (('MUSLIMS', 'NORP'), 3),
#  (('THREE', 'CARDINAL'), 3),
#  (('KAPLAN', 'PERSON'), 3),
#  (('THIEL', 'PERSON'), 3),
#  (('POST', 'ORG'), 3)]

# %% [markdown]
# ### 5. Find Entites and their dependency (hint: entity.root.head)

# %%
for entity in processed_text.ents:
    print(entity, entity.root.head)
# Out:
# Zuckerberg wanted
# Trump sanction
# Facebook wrote
# as early as 2015 Starting
# Facebook executives
# years for
# Trump post
# last month post
# Minnesota protests
# Trump called
# Facebook executive
# Mark Zuckerberg called
# Zuckerberg told
# Trump told
# Facebook To
# Washington in
# the White House contacted
# earlier in the day contacted
# Trump posted
# Zuckerberg went
# Trump explanation
# five-year struggle
# Facebook by
# Trump of
# Facebook start
# Facebook constrained
# more than a dozen employees
# The Washington Post by
# One shows
# 2015 as
# Trump posted
# Muslims of
# the United States entering
# Facebook executives
# Trump to
# billions to
# Trump grew
# Facebook pushed
# Facebook confronting
# Starbucks became
# Sunday on
# Facebook facing
# more than 5,000 employees
# Trump leave
# Friday on
# Zuckerberg announced
# the United States heads
# Trump to
# recent months In
# Facebook used
# Facebook places
# Silicon Valley in
# Snapchat curtailed
# Facebook for
# David Thiel said
# Facebook engineer
# March in
# Brazil by
# Facebook contends
# Nick Clegg said
# Facebook president
# Silicon Valley in
# Nick Clegg said
# Facebook president
# Silicon Valley in
# Kirsty Wigglesworth/AP AP
# the Arab Spring From
# Facebook declined
# Zuckerberg available
# Zuckerberg opposed
# Trump opposed
# Muslim ban
# The White House declined
# Zuckerberg talks
# Facebook of
# WhatsApp Facebook
# Instagram WhatsApp
# monthly users
# many years for
# one point
# Trump to
# 2016 election
# 2015 in
# Trump candidacy
# December of that year In
# Muslims ban
# the United States entering
# Facebook on
# three employees
# Zuckerberg expressed
# one At
# Monika Bickert drafted
# Facebook president
# Zuckerberg including
# Sheryl Sandberg Zuckerberg
# Joel Kaplan of
# Republican company
# The Post by
# four options
# one time
# Get the gays out of San Francisco allowed
# Facebook spokesman
# Tucker Bounds said
# Would Facebook provided
# Hitler for
# Bickert wrote
# Zuckerberg talked
# Kaplan by
# the next several years for
# October 2016 in
# Kaplan by
# Trump role
# Bickert said
# Trump video
# Muslim video
# Trump interpreted
# Muslims about
# Facebook Bounds
# Bounds added
# 2016 in
# the Vietnam War during
# spring of 2016 In
# Zuckerberg talked
# Trump condemning
# the United States between
# Mexico States
# Washington in
# Dex Torricke-Barton to
# Zuckerberg of
# Rodrigo Duterte as
# Philippines in
# Jair Bolsonaro Duterte
# Brazil in
# Narendra Modi Bolsonaro
# India in
# Claire Wardle said
# U.S. director
# First Draft of
# Facebook with
# Trump presented
# Russia used
# Facebook became
# anti-Trump was
# GOP leaders
# Facebook as
# Twitter Facebook
# Trump supporting
# Facebook spokesman
# Nu Wexler said
# 2018 in
# Facebook scrambled
# three people
# Facebook engineers
# December 2016 in
# Facebook team
# dozens highlighted
# Washington in
# Kaplan including
# A year later considered
# Facebook considered
# Kaplan questioned
# three people
# 2020 election
# Facebook horizon
# Zuckerberg Facebook
# Silicon Valley in
# May 2019 In
# Zuckerberg refused
# House Speaker
# Nancy Pelosi of
# D-Calif. Pelosi
# That summer held
# Zuckerberg by
# two people
# British minister
# Washington in
# September 2019 in
# Facebook allow
# Facebook network
# Facebook want
# Zuckerberg position
# more than 250 triggering
# One executive
# Yael Eisenstat executive
# The Post in
# Facebook put
# October in
# Facebook faced
# Zuckerberg went
# Priscilla Chan wife
# the White House to
# Trump with
# Washington in
# the first half of this year dominated
# Trump continued
# George Floyd protests
# Facebook employees
# Two months before
# Trump before
# Brazilian president
# Indians changing
# Thiel argued
# Zuckerberg to
# Congress before
# October in
# first step
# Thiel told
# Thiel quit
# May In
# years following
# two tweets
# Trump by
# two days later responded
# Trump speaks
# William P. Barr with
# the Oval Office in
# May 28 on
# The next day tweeted
# Trump tweeted
# Minnesota protests
# Snapchat stopped
# Trump promoting
# the following week account
# YouTube told
# Post told
# Facebook chose
# the White House with
# Facebook Bounds
# Bounds confirmed
# Post to
# Zuckerberg told
# Facebook policies
# Trump post
# Bickert team
# the weeks ahead for
# June In
# Facebook removed
# Trump ads
# Nazi symbolism
# Post by
# Last week picked
# Hershey, said
# Verizon Hershey
# Unilever Verizon
# Coca-Cola Unilever
# Friday On
# Zuckerberg told
# Twitter does
# today announcing
# Zuckerberg said

# %% [markdown]
# ### 6. Find the most similar words (noun chunks) in the article

# %%
import gensim
from gensim import corpora
from pprint import pprint
from gensim.utils import simple_preprocess
from smart_open import smart_open
import os

# %%
dict = corpora.Dictionary(
   simple_preprocess(line, deacc =True) for line in open('../data/doc.txt')
)

# %%
print(dict)
# Out:
# Dictionary(1004 unique tokens: ['about', 'after', 'called', 'chief', 'executive']...)

# %%
print(dict.token2id)
# Out:
# {'about': 0, 'after': 1, 'called': 2, 'chief': 3, 'executive': 4, 'facebook': 5, 'hours': 6, 'incendiary': 7, 'last': 8, 'mark': 9, 'military': 10, 'minnesota': 11, 'month': 12, 'post': 13, 'president': 14, 'protests': 15, 'sending': 16, 'the': 17, 'to': 18, 'trump': 19, 'zuckerberg': 20, 'according': 21, 'action': 22, 'against': 23, 'by': 24, 'company': 25, 'difficult': 26, 'discussions': 27, 'ever': 28, 'familiar': 29, 'hidden': 30, 'in': 31, 'message': 32, 'people': 33, 'position': 34, 'presidential': 35, 'put': 36, 'same': 37, 'strongest': 38, 'taken': 39, 'told': 40, 'twitter': 41, 'was': 42, 'with': 43, 'allows': 44, 'already': 45, 'an': 46, 'appear': 47, 'but': 48, 'came': 49, 'contacted': 50, 'day': 51, 'delete': 52, 'deputies': 53, 'didn': 54, 'earlier': 55, 'executives': 56, 'force': 57, 'government': 58, 'had': 59, 'house': 60, 'if': 61, 'intended': 62, 'is': 63, 'it': 64, 'its': 65, 'language': 66, 'leaders': 67, 'line': 68, 'of': 69, 'or': 70, 'plea': 71, 'policies': 72, 'public': 73, 'right': 74, 'said': 75, 'simply': 76, 'tweak': 77, 'up': 78, 'urgent': 79, 'use': 80, 'violate': 81, 'warn': 82, 'washington': 83, 'which': 84, 'white': 85, 'again': 86, 'all': 87, 'be': 88, 'comments': 89, 'decision': 90, 'eventually': 91, 'explain': 92, 'explanation': 93, 'for': 94, 'helped': 95, 'him': 96, 'his': 97, 'keeping': 98, 'make': 99, 'noting': 100, 'online': 101, 'posted': 102, 'rationale': 103, 'saying': 104, 'subsequent': 105, 'supposed': 106, 'that': 107, 'then': 108, 'warning': 109, 'went': 110, 'were': 111, 'accommodate': 112, 'altered': 113, 'and': 114, 'boundary': 115, 'busting': 116, 'candidate': 117, 'certain': 118, 'changed': 119, 'continually': 120, 'five': 121, 'frenzied': 122, 'has': 123, 'he': 124, 'incident': 125, 'just': 126, 'latest': 127, 'not': 128, 'outlast': 129, 'presidency': 130, 'products': 131, 'pull': 132, 'push': 133, 'rhetoric': 134, 'since': 135, 'struggle': 136, 'ways': 137, 'year': 138, 'bowing': 139, 'critics': 140, 'enough': 141, 'from': 142, 'labeling': 143, 'politicians': 144, 'posts': 145, 'pressure': 146, 'say': 147, 'start': 148, 'violating': 149, 'will': 150, 'adopted': 151, 'algorithm': 152, 'allowing': 153, 'as': 154, 'back': 155, 'ban': 156, 'began': 157, 'biased': 158, 'calling': 159, 'claims': 160, 'conservative': 161, 'constrained': 162, 'current': 163, 'declined': 164, 'discourse': 165, 'documents': 166, 'dozen': 167, 'efforts': 168, 'employees': 169, 'entering': 170, 'even': 171, 'exception': 172, 'explicitly': 173, 'false': 174, 'far': 175, 'feed': 176, 'former': 177, 'lie': 178, 'misleading': 179, 'more': 180, 'motion': 181, 'muslims': 182, 'neutralize': 183, 'news': 184, 'obtained': 185, 'one': 186, 'policy': 187, 'political': 188, 'previously': 189, 'publishers': 190, 'remove': 191, 'setting': 192, 'shows': 193, 'states': 194, 'than': 195, 'united': 196, 'unreported': 197, 'video': 198, 'when': 199, 'battlefield': 200, 'billions': 201, 'complicated': 202, 'concessions': 203, 'contributed': 204, 'digitally': 205, 'events': 206, 'growing': 207, 'have': 208, 'information': 209, 'led': 210, 'list': 211, 'major': 212, 'misinformation': 213, 'movement': 214, 'out': 215, 'pandemic': 216, 'paved': 217, 'polarization': 218, 'protest': 219, 'repeatedly': 220, 'savvy': 221, 'such': 222, 'they': 223, 'transformation': 224, 'understanding': 225, 'way': 226, 'well': 227, 'world': 228, 'balance': 229, 'behavior': 230, 'deferential': 231, 'fear': 232, 'grew': 233, 'into': 234, 'leaning': 235, 'network': 236, 'number': 237, 'on': 238, 'power': 239, 'pushed': 240, 'see': 241, 'tilting': 242, 'toward': 243, 'users': 244, 'wrath': 245, 'advertiser': 246, 'advertising': 247, 'became': 248, 'boycott': 249, 'companies': 250, 'confronting': 251, 'demand': 252, 'down': 253, 'hate': 254, 'hit': 255, 'media': 256, 'mounting': 257, 'now': 258, 'pause': 259, 'price': 260, 'social': 261, 'speech': 262, 'starbucks': 263, 'stock': 264, 'stricter': 265, 'sunday': 266, 'would': 267, 'also': 268, 'burnin ...

# %%
for key in dict:
    print (key, token2id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-69e06b752650> in <module>
# ----> 1 for key in dict:
#       2     print (key, token2id)
#       3
#
# TypeError: 'type' object is not iterable
